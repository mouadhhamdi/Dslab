# %% [markdown]
# # Homework 4

# %% [markdown]
# ## More trains

# %% [markdown]
# For this homework, you will be working with the real-time stream of the NS, the train company of the Netherlands. You can see an example webpage that uses this same stream to display the train information on a map: https://spoorkaart.mwnn.nl/ .
#
# To help you and avoid having too many connections to the NS streaming servers, we have setup a service that collects the streams and pushes them to our Kafka instance. The related topics are:
#
# `ndovloketnl-arrivals` : For each arrival of a train in a station, describe the previous and next station, time of arrival (planned and actual), track number,...
#
# `ndovloketnl-departures`: For each departure of a train from a station, describe the previous and next station, time of departure (planned and actual), track number,...
#
# `ndovloketnl-gps`: For each train, describe the current location, speed, bearing.
#
# The events are serialized in json (actually converted from xml), with properties in their original language. Google translate could help you understand all of them, but we will provide you some useful mapping.

# %% [markdown]
# ## Start a Spark Session

# %%
import pyspark
from pyspark.sql import SparkSession
import os
import getpass
from pyspark.streaming import StreamingContext
from  pyspark.streaming.kafka import KafkaUtils, OffsetRange

username = getpass.getuser()

# Use this when running on your computer
spark = (SparkSession
         .builder
         .appName('streaming-{0}'.format(username))
         .master('local[4]') # this number must be greater than the number of sources
         .config('spark.executor.memory', '1g')
         .config('spark.jars.packages', 'org.apache.spark:spark-streaming-kafka-0-8_2.11:2.2.0')
         .getOrCreate())

# Use this when running on the cluster
#os.environ['PYSPARK_PYTHON'] = '/opt/anaconda3/bin/python'
#spark = (SparkSession
#          .builder
#          .appName('streaming-{0}'.format(username))
#          .master('yarn')
#          .config('spark.executor.memory', '1g')
#          .config('spark.executor.instances', '2')
#          .config('spark.executor.cores', '2')
#          .config('spark.jars.packages', 'org.apache.spark:spark-streaming-kafka-0-8_2.11:2.2.0')
#          .config('spark.port.maxRetries', '100')
#          .getOrCreate())

sc = spark.sparkContext
conf = sc.getConf()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://vpn-253-102.epfl.ch:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[4]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>streaming-abouzaid</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Start a Kafka Client

# %%
from pykafka import KafkaClient

ZOOKEEPER_QUORUM = 'iccluster045.iccluster.epfl.ch:2181,iccluster047.iccluster.epfl.ch:2181,iccluster058.iccluster.epfl.ch:2181'

client = KafkaClient(zookeeper_hosts=ZOOKEEPER_QUORUM)

# %%
len(client.topics)
# Out:
# 283

# %% [markdown]
# # Preliminary - Data Preparation
#
# ## Static RDDs from Kafka
#
# Working on data streams is often times more complex compared to using static datasets, so we will first look at how to create static RDDs for easy prototyping.

# %% [markdown]
# You can find below a function that creates a static RDD from a Kafka topic.

# %%
def create_static_rdd_from_kafka(topic, from_offset, to_offset):
    if isinstance(topic, bytes):
        topic = topic.decode('utf-8')
    return KafkaUtils.createRDD(sc, {'bootstrap.servers': 'iccluster045.iccluster.epfl.ch:6667'}, [OffsetRange(topic, 0, from_offset, to_offset)])

# %% [markdown]
# To check this function, we need to retrieve valid offsets from Kafka.

# %%
topic = client.topics[b'ndovloketnl-arrivals']
topic.earliest_available_offsets()
# Out:
# {0: OffsetPartitionResponse(offset=[408075], err=0)}

# %% [markdown]
# Now, we can for example retrieve the first 1000 messages from the topic `ndovloketnl-arrivals`.

# %%
offset = topic.earliest_available_offsets()[0].offset[0]
rdd = create_static_rdd_from_kafka(b'ndovloketnl-arrivals', offset, offset+1000)

# %%
rdd.first()
# Out:
# (None,
#  '{"ns1:PutReisInformatieBoodschapIn": {"@xmlns:ns1": "urn:ndov:cdm:trein:reisinformatie:messages:dynamischeaankomststaat:1", "@xmlns:ns2": "urn:ndov:cdm:trein:reisinformatie:data:4", "ns2:ReisInformatieProductDAS": {"@TimeStamp": "2018-04-28T21:07:58.090Z", "@Versie": "6.1", "ns2:RIPAdministratie": {"ns2:ReisInformatieProductID": "1804282307582200002", "ns2:AbonnementId": "55", "ns2:ReisInformatieTijdstip": "2018-04-28T21:07:00.000Z"}, "ns2:DynamischeAankomstStaat": {"ns2:RitId": "7079", "ns2:RitDatum": "2018-04-28", "ns2:RitStation": {"ns2:StationCode": "AML", "ns2:Type": "5", "ns2:KorteNaam": "Almelo", "ns2:MiddelNaam": "Almelo", "ns2:LangeNaam": "Almelo", "ns2:UICCode": "8400051"}, "ns2:TreinAankomst": {"ns2:TreinNummer": "7079", "ns2:TreinSoort": {"@Code": "SPR", "#text": "Sprinter"}, "ns2:TreinStatus": "0", "ns2:Vervoerder": "NS", "ns2:TreinHerkomst": [{"@InfoStatus": "Gepland", "ns2:StationCode": "APD", "ns2:Type": "5", "ns2:KorteNaam": "Apeldoorn", "ns2:MiddelNaam": "Apeldoorn", "ns2:LangeNaam": "Apeldoorn", "ns2:UICCode": "8400066"}, {"@InfoStatus": "Actueel", "ns2:StationCode": "APD", "ns2:Type": "5", "ns2:KorteNaam": "Apeldoorn", "ns2:MiddelNaam": "Apeldoorn", "ns2:LangeNaam": "Apeldoorn", "ns2:UICCode": "8400066"}], "ns2:PresentatieTreinHerkomst": {"ns2:Uitingen": {"ns2:Uiting": "Apeldoorn"}}, "ns2:AankomstTijd": [{"@InfoStatus": "Gepland", "#text": "2018-04-28T21:07:00.000Z"}, {"@InfoStatus": "Actueel", "#text": "2018-04-28T21:10:12.000Z"}], "ns2:ExacteAankomstVertraging": "PT3M12S", "ns2:PresentatieAankomstVertraging": {"ns2:Uitingen": {"ns2:Uiting": "+3 min."}}, "ns2:GedempteAankomstVertraging": "PT5M", "ns2:TreinAankomstSpoor": [{"@InfoStatus": "Gepland", "ns2:SpoorNummer": "2", "ns2:SpoorFase": "a"}, {"@InfoStatus": "Actueel", "ns2:SpoorNummer": "2", "ns2:SpoorFase": "a"}], "ns2:PresentatieTreinAankomstSpoor": {"ns2:Uitingen": {"ns2:Uiting": "2a"}}, "ns2:VerkorteRouteHerkomst": [{"@InfoStatus": "Gepland", "ns2:Station": [{"ns2:StationCode": "DV", "ns2:Type": "5", "ns2:KorteNaam": "Deventer", "ns2:MiddelNaam": "Deventer", "ns2:LangeNaam": "Deventer", "ns2:UICCode": "8400173"}, {"ns2:StationCode": "WDN", "ns2:Type": "1", "ns2:KorteNaam": "Wierden", "ns2:MiddelNaam": "Wierden", "ns2:LangeNaam": "Wierden", "ns2:UICCode": "8400691"}]}, {"@InfoStatus": "Actueel", "ns2:Station": [{"ns2:StationCode": "DV", "ns2:Type": "5", "ns2:KorteNaam": "Deventer", "ns2:MiddelNaam": "Deventer", "ns2:LangeNaam": "Deventer", "ns2:UICCode": "8400173"}, {"ns2:StationCode": "WDN", "ns2:Type": "1", "ns2:KorteNaam": "Wierden", "ns2:MiddelNaam": "Wierden", "ns2:LangeNaam": "Wierden", "ns2:UICCode": "8400691"}]}], "ns2:PresentatieVerkorteRouteHerkomst": {"ns2:Uitingen": {"ns2:Uiting": "Deventer, Wierden"}}, "ns2:WijzigingHerkomst": {"ns2:WijzigingType": "11"}}}}}}')

# %%
rdd.count()
# Out:
# 1000

# %% [markdown]
# We encourage you to use these functions to help prototype your code.

# %% [markdown]
# ## Fetching messages at specific offsets from Kafka

# %% [markdown]
# You can find below a function to read a message at a specific offset from a Kafka topic.

# %%
def fetch_message_at(topic, offset):
    if isinstance(topic, str):
        topic = topic.encode('utf-8')
    t = client.topics[topic]
    consumer = t.get_simple_consumer()
    p = list(consumer.partitions.values())[0]
    consumer.reset_offsets([(p,int(offset)-1)], )
    return consumer.consume()

# %%
msg = fetch_message_at(b'ndovloketnl-arrivals', 408076)
# Out:
# Offset reset for partition 0 to timestamp 408075 failed. Setting partition 0's internal counter to 408075

# %%
msg.offset
# Out:
# 408076

# %%
msg.value
# Out:
# b'{"ns1:PutReisInformatieBoodschapIn": {"@xmlns:ns1": "urn:ndov:cdm:trein:reisinformatie:messages:dynamischeaankomststaat:1", "@xmlns:ns2": "urn:ndov:cdm:trein:reisinformatie:data:4", "ns2:ReisInformatieProductDAS": {"@TimeStamp": "2018-04-28T21:08:03.600Z", "@Versie": "6.1", "ns2:RIPAdministratie": {"ns2:ReisInformatieProductID": "1804282308032400018", "ns2:AbonnementId": "55", "ns2:ReisInformatieTijdstip": "2018-04-28T21:12:00.000Z"}, "ns2:DynamischeAankomstStaat": {"ns2:RitId": "4383", "ns2:RitDatum": "2018-04-28", "ns2:RitStation": {"ns2:StationCode": "ALM", "ns2:Type": "5", "ns2:KorteNaam": "Almere C", "ns2:MiddelNaam": "Almere C.", "ns2:LangeNaam": "Almere Centrum", "ns2:UICCode": "8400080"}, "ns2:TreinAankomst": {"ns2:TreinNummer": "4383", "ns2:TreinSoort": {"@Code": "SPR", "#text": "Sprinter"}, "ns2:TreinStatus": "0", "ns2:Vervoerder": "NS", "ns2:TreinHerkomst": [{"@InfoStatus": "Gepland", "ns2:StationCode": "HFD", "ns2:Type": "0", "ns2:KorteNaam": "Hoofddorp", "ns2:MiddelNaam": "Hoofddorp", "ns2:LangeNaam": "Hoofddorp", "ns2:UICCode": "8400332"}, {"@InfoStatus": "Actueel", "ns2:StationCode": "HFD", "ns2:Type": "0", "ns2:KorteNaam": "Hoofddorp", "ns2:MiddelNaam": "Hoofddorp", "ns2:LangeNaam": "Hoofddorp", "ns2:UICCode": "8400332"}], "ns2:PresentatieTreinHerkomst": {"ns2:Uitingen": {"ns2:Uiting": "Hoofddorp"}}, "ns2:AankomstTijd": [{"@InfoStatus": "Gepland", "#text": "2018-04-28T21:12:00.000Z"}, {"@InfoStatus": "Actueel", "#text": "2018-04-28T21:12:00.000Z"}], "ns2:ExacteAankomstVertraging": "PT0S", "ns2:GedempteAankomstVertraging": "PT0S", "ns2:TreinAankomstSpoor": [{"@InfoStatus": "Gepland", "ns2:SpoorNummer": "4"}, {"@InfoStatus": "Actueel", "ns2:SpoorNummer": "4"}], "ns2:PresentatieTreinAankomstSpoor": {"ns2:Uitingen": {"ns2:Uiting": "4"}}, "ns2:VerkorteRouteHerkomst": [{"@InfoStatus": "Gepland", "ns2:Station": [{"ns2:StationCode": "SHL", "ns2:Type": "6", "ns2:KorteNaam": "Schiphol", "ns2:MiddelNaam": "Schiphol Airport", "ns2:LangeNaam": "Schiphol Airport", "ns2:UICCode": "8400561"}, {"ns2:StationCode": "DVD", "ns2:Type": "1", "ns2:KorteNaam": "Duivendrt", "ns2:MiddelNaam": "Duivendrecht", "ns2:LangeNaam": "Duivendrecht", "ns2:UICCode": "8400194"}, {"ns2:StationCode": "WP", "ns2:Type": "1", "ns2:KorteNaam": "Weesp", "ns2:MiddelNaam": "Weesp", "ns2:LangeNaam": "Weesp", "ns2:UICCode": "8400685"}]}, {"@InfoStatus": "Actueel", "ns2:Station": [{"ns2:StationCode": "SHL", "ns2:Type": "6", "ns2:KorteNaam": "Schiphol", "ns2:MiddelNaam": "Schiphol Airport", "ns2:LangeNaam": "Schiphol Airport", "ns2:UICCode": "8400561"}, {"ns2:StationCode": "DVD", "ns2:Type": "1", "ns2:KorteNaam": "Duivendrt", "ns2:MiddelNaam": "Duivendrecht", "ns2:LangeNaam": "Duivendrecht", "ns2:UICCode": "8400194"}, {"ns2:StationCode": "WP", "ns2:Type": "1", "ns2:KorteNaam": "Weesp", "ns2:MiddelNaam": "Weesp", "ns2:LangeNaam": "Weesp", "ns2:UICCode": "8400685"}]}], "ns2:PresentatieVerkorteRouteHerkomst": {"ns2:Uitingen": {"ns2:Uiting": "Schiphol Airport, Duivendrecht, Weesp"}}}}}}}'

# %% [markdown]
# ## Streams from Kafka

# %%
# Define the checkpoint folder

# Use this if working on your computer
checkpoint = '/tmp/checkpoint'

# Use this if working on the cluster
#checkpoint = 'hdfs:///user/{}/checkpoint/'.format(username)

# %%
# Create a StreamingContext with two working thread and batch interval of 10 seconds.
# Each time you stop a StreamingContext, you will need to recreate it.
ssc = StreamingContext(sc, 10)
ssc.checkpoint(checkpoint)

group_id = 'ns-{0}'.format(username)

# Input streams
arrival_stream = KafkaUtils.createStream(ssc, ZOOKEEPER_QUORUM, group_id, {'ndovloketnl-arrivals': 1})
departure_stream = KafkaUtils.createStream(ssc, ZOOKEEPER_QUORUM, group_id, {'ndovloketnl-departures': 1})
gps_stream = KafkaUtils.createStream(ssc, ZOOKEEPER_QUORUM, group_id, {'ndovloketnl-gps': 1})

# %% [markdown]
# For now, let's just print the content of the streams

# %%
arrival_stream.pprint()
departure_stream.pprint()
gps_stream.pprint()

ssc.start()
# Out:
# -------------------------------------------
# Time: 2018-05-18 17:00:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:00:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:00:40
# -------------------------------------------

# %%
ssc.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2018-05-18 17:00:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:00:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:00:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:01:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:01:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 17:01:00
# -------------------------------------------

# %% [markdown]
# You will need to adjust the batch interval (10 seconds here) in accordance with the processing times. Use the spark UI to check if batches are not accumulating.

# %% [markdown]
# # Part I - Live plot (20 points / 60)
#
# The goal of this part is to obtain an interactive plot use the train positions from the GPS stream. We encourage you to use the examples from last week to achieve the expected result.

# %% [markdown]
# First, let's write a function to decode the messages from the `ndovloketnl-gps` topic.

# %%
import json
from pykafka.common import OffsetType

example_gps = client.topics[b'ndovloketnl-gps'].get_simple_consumer(
    auto_offset_reset=OffsetType.EARLIEST,
    reset_offset_on_start=True
).consume()
json.loads(example_gps.value)
# Out:
# {'tns:ArrayOfTreinLocation': {'@xmlns:tns': 'http://schemas.datacontract.org/2004/07/Cognos.Infrastructure.Models',
#   'tns:TreinLocation': [{'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.5608216667',
#       'tns:Longitude': '5.0829',
#       'tns:MaterieelDeelNummer': '4240',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '150.96',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.56064',
#       'tns:Longitude': '5.08481666667',
#       'tns:MaterieelDeelNummer': '4032',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '36.95',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '3671'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.678516391842',
#      'tns:Longitude': '4.8996640175703',
#      'tns:MaterieelDeelNummer': '2961',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '90.9',
#      'tns:Snelheid': '50.4'},
#     'tns:TreinNummer': '4873'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.5958383333',
#       'tns:Longitude': '4.79456333333',
#       'tns:MaterieelDeelNummer': '4064',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '86.01',
#       'tns:Snelheid': '38.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.5958383333',
#       'tns:Longitude': '4.79422',
#       'tns:MaterieelDeelNummer': '4244',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '86.23',
#       'tns:Snelheid': '51.0'}],
#     'tns:TreinNummer': '3674'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.87381',
#       'tns:Longitude': '5.85875833333',
#       'tns:MaterieelDeelNummer': '4060',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '357.03',
#       'tns:Snelheid': '134.0'},
#      {'tns:AantalSatelieten': '10',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.87345',
#       'tns:Longitude': '5.85880333333',
#       'tns:MaterieelDeelNummer': '4241',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '357.01',
#       'tns:Snelheid': '135.0'}],
#     'tns:TreinNummer': '3670'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.362051626752',
#      'tns:Longitude': '4.9310855568925',
#      'tns:MaterieelDeelNummer': '2410',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '172.6',
#      'tns:Snelheid': '43.2'},
#     'tns:TreinNummer': '14675'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '10',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.9852116667',
#      'tns:Longitude': '5.90010166667',
#      'tns:MaterieelDeelNummer': '9402',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '114.24',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '3072'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.64',
#       'tns:Latitude': '52.1068345',
#       'tns:Longitude': '5.08332333333',
#       'tns:MaterieelDeelNummer': '9576',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '313.22',
#       'tns:Snelheid': '112.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.1060966667',
#       'tns:Longitude': '5.08451333333',
#       'tns:MaterieelDeelNummer': '9522',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '313.06',
#       'tns:Snelheid': '112.0'}],
#     'tns:TreinNummer': '3170'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.355876035642',
#       'tns:Longitude': '4.9198526270407',
#       'tns:MaterieelDeelNummer': '2416',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '244.9',
#       'tns:Snelheid': '64.8'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.356496909211',
#       'tns:Longitude': '4.9220207911214',
#       'tns:MaterieelDeelNummer': '2411',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '244.2',
#       'tns:Snelheid': '64.8'}],
#     'tns:TreinNummer': '4077'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:17Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.01148166349',
#       'tns:Longitude': '4.6367337018792',
#       'tns:MaterieelDeelNummer': '2460',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '292.1',
#       'tns:Snelheid': '126.0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.011156186449',
#       'tns:Longitude': '4.6380594260477',
#       'tns:MaterieelDeelNummer': '2621',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '292.1',
#       'tns:Snelheid': '122.4'}],
#     'tns:TreinNummer': '7866'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.63',
#      'tns:Latitude': '52.6394338333',
#      'tns:Longitude': '6.22614533333',
#      'tns:MaterieelDeelNummer': '7617',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '329.86',
#      'tns:Snelheid': '126.0'},
#     'tns:TreinNummer': '769'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.085304668655',
#       'tns:Longitude': '4.894688140372',
#       'tns:MaterieelDeelNummer': '2436',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:18Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.08494481708',
#       'tns:Longitude': '4.893708016236',
#       'tns:MaterieelDeelNummer': '2650',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '59.5',
#       'tns:Snelheid': '10.8'}],
#     'tns:TreinNummer': '7877'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.2449316667',
#       'tns:Longitude': '5.7614',
#       'tns:MaterieelDeelNummer': '8644',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '96.15',
#       'tns:Snelheid': '136.0'},
#      {'tns:AantalSatelieten': '10',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.2451633333',
#       'tns:Longitude': '5.75796166667',
#       'tns:MaterieelDeelNummer': '9420',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '96.25',
#       'tns:Snelheid': '136.0'}],
#     'tns:TreinNummer': '3969'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.256175',
#      'tns:Longitude': '6.171555',
#      'tns:MaterieelDeelNummer': '4208',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '249.39',
#      'tns:Snelheid': '38.0'},
#     'tns:TreinNummer': '701774'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#      'tns:Hdop': '0.66',
#      'tns:Latitude': '51.8447655',
#      'tns:Longitude': '5.85287783333',
#      'tns:MaterieelDeelNummer': '2209',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '197.7',
#      'tns:Snelheid': '38.0'},
#     'tns:TreinNummer': '7672'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.92568',
#       'tns:Longitude': '4.469375',
#       'tns:MaterieelDeelNummer': '4073',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '54.94',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.92541',
#       'tns:Longitude': '4.46818',
#       'tns:MaterieelDeelNummer': '4219',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '55.78',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '666'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.03207',
#      'tns:Longitude': '5.64895166667',
#      'tns:MaterieelDeelNummer': '8730',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '286.65',
#      'tns:Snelheid': '110.0'},
#     'tns:TreinNummer': '3172'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#       'tns:Hdop': '0.64',
#       'tns:Latitude': '51.9008016667',
#       'tns:Longitude': '5.85642383333',
#       'tns:MaterieelDeelNummer': '9595',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '177.08',
#       'tns:Snelheid': '123.0'},
#      {'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.64',
#       'tns:Latitude': '51.8979871667',
#       'tns:Longitude': '5.856662',
#       'tns:MaterieelDeelNummer': '9478',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '176.97',
#       'tns:Snelheid': '119.0'}],
#     'tns:TreinNummer': '3171'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.4746216667',
#      'tns:Longitude': '5.65818666667',
#      'tns:MaterieelDeelNummer': '8739',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '69.69',
#      'tns:Snelheid': '62.0'},
#     'tns:TreinNummer': '3569'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.807802169375',
#       'tns:Longitude': '5.2633596252503',
#       'tns:MaterieelDeelNummer': '2450',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '173.4',
#       'tns:Snelheid': '18.0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '51.807572361917',
#       'tns:Longitude': '5.2633838903664',
#       'tns:MaterieelDeelNummer': '2445',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '173.2',
#       'tns:Snelheid': '46.8'}],
#     'tns:TreinNummer': '6973'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.3469',
#      'tns:Longitude': '4.91753666667',
#      'tns:MaterieelDeelNummer': '8615',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '339.36',
#      'tns:Snelheid': '28.0'},
#     'tns:TreinNummer': '3068'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.339065',
#      'tns:Longitude': '5.15144833333',
#      'tns:MaterieelDeelNummer': '7632',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '7.79',
#      'tns:Snelheid': '130.0'},
#     'tns:TreinNummer': '773'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '51.889927962182',
#      'tns:Longitude': '5.423207268975',
#      'tns:MaterieelDeelNummer': '2661',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '6071'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '10',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.9906566667',
#      'tns:Longitude': '6.57081',
#      'tns:MaterieelDeelNummer': '7649',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '52.94',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '567'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.904745328443',
#       'tns:Longitude': '4.5100875217142',
#       'tns:MaterieelDeelNummer': '2993',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.904363390982',
#       'tns:Longitude': '4.5104841320159',
#       'tns:MaterieelDeelNummer': '2963',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '5170'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.37632876273',
#      'tns:Longitude': '5.2283624861021',
#      'tns:MaterieelDeelNummer': '2634',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '85.4',
#      'tns:Snelheid': '82.8'},
#     'tns:TreinNummer': '14673'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.423875',
#      'tns:Longitude': '4.142',
#      'tns:MaterieelDeelNummer': '9561',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '290.99',
#      'tns:Snelheid': '97.0'},
#     'tns:TreinNummer': '702260'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.1651266667',
#      'tns:Longitude': '5.96517833333',
#      'tns:MaterieelDeelNummer': '8729',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '45.57',
#      'tns:Snelheid': '130.0'},
#     'tns:TreinNummer': '876'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '8',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#       'tns:Hdop': '1.0',
#       'tns:Latitude': '52.0183583333',
#       'tns:Longitude': '4.78895333333',
#       'tns:MaterieelDeelNummer': '7522',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '55.98',
#       'tns:Snelheid': '124.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.0169933333',
#       'tns:Longitude': '4.78561',
#       'tns:MaterieelDeelNummer': '7542',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '58.28',
#       'tns:Snelheid': '124.0'}],
#     'tns:TreinNummer': '575'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '8',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '1.0',
#       'tns:Latitude': '51.000795',
#       'tns:Longitude': '5.85833',
#       'tns:MaterieelDeelNummer': '9583',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '81.16',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.0021516667',
#       'tns:Longitude': '5.85914666667',
#       'tns:MaterieelDeelNummer': '8670',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '74.11',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '3967'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.766245',
#       'tns:Longitude': '5.536495',
#       'tns:MaterieelDeelNummer': '4013',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '267.41',
#       'tns:Snelheid': '51.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.7662833333',
#       'tns:Longitude': '5.53685833333',
#       'tns:MaterieelDeelNummer': '4210',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '268.07',
#       'tns:Snelheid': '49.0'}],
#     'tns:TreinNummer': '3673'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.132013521601',
#      'tns:Longitude': '5.1504272115665',
#      'tns:MaterieelDeelNummer': '2446',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '202.5',
#      'tns:Snelheid': '100.8'},
#     'tns:TreinNummer': '4971'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.148165',
#       'tns:Longitude': '6.19968666667',
#       'tns:MaterieelDeelNummer': '4057',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '217.6',
#       'tns:Snelheid': '45.0'},
#      {'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.63',
#       'tns:Latitude': '52.1491148333',
#       'tns:Longitude': '6.20091',
#       'tns:MaterieelDeelNummer': '4061',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '217.6',
#       'tns:Snelheid': '47.0'}],
#     'tns:TreinNummer': '3677'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.003690400046',
#      'tns:Longitude': '5.560031599535',
#      'tns:MaterieelDeelNummer': '2978',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '340.3',
#      'tns:Snelheid': '97.2'},
#     'tns:TreinNummer': '7370'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '1.0',
#      'tns:Latitude': '52.167452985177',
#      'tns:Longitude': '4.4838599901943',
#      'tns:MaterieelDeelNummer': '2609',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '4679'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.37705',
#      'tns:Longitude': '4.91031',
#      'tns:MaterieelDeelNummer': '8638',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '82.43',
#      'tns:Snelheid': '26.0'},
#     'tns:TreinNummer': '3075'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.292315',
#      'tns:Longitude': '6.75489333333',
#      'tns:MaterieelDeelNummer': '4222',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '328.59',
#      'tns:Snelheid': '127.0'},
#     'tns:TreinNummer': '701676'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '53.1600466667',
#       'tns:Longitude': '6.62935333333',
#       'tns:MaterieelDeelNummer': '4246',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '79.56',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.532695',
#       'tns:Longitude': '5.73477833333',
#       'tns:MaterieelDeelNummer': '4018',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '101.33',
#       'tns:Snelheid': '138.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.5330783333',
#       'tns:Longitude': '5.73170833333',
#       'tns:MaterieelDeelNummer': '4215',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '101.3',
#       'tns:Snelheid': '138.0'}],
#     'tns:TreinNummer': '1871'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '3',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T04:29:14Z',
#      'tns:Hdop': '9.8',
#      'tns:Latitude': '51.9235383333',
#      'tns:Longitude': '4.464945',
#      'tns:MaterieelDeelNummer': '9417',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '2268'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#       'tns:Hdop': '0.64',
#       'tns:Latitude': '51.689522',
#       'tns:Longitude': '4.66426266667',
#       'tns:MaterieelDeelNummer': '2201',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '339.89',
#       'tns:Snelheid': '64.0'},
#      {'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.65',
#       'tns:Latitude': '51.6891373333',
#       'tns:Longitude': '4.66446166667',
#       'tns:MaterieelDeelNummer': '2221',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '340.62',
#       'tns:Snelheid': '61.0'}],
#     'tns:TreinNummer': '6669'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.6779966667',
#      'tns:Longitude': '5.29145666667',
#      'tns:MaterieelDeelNummer': '8727',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '174.64',
#      'tns:Snelheid': '67.0'},
#     'tns:TreinNummer': '3571'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.1538016667',
#      'tns:Longitude': '5.37259333333',
#      'tns:MaterieelDeelNummer': '7538',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '66.33',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '670'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.375614156853',
#       'tns:Longitude': '4.5321500304457',
#       'tns:MaterieelDeelNummer': '2948',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.375440589588',
#       'tns:Longitude': '4.532845960985',
#       'tns:MaterieelDeelNummer': '2117',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '5481'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '10',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.529035',
#      'tns:Longitude': '5.86554166667',
#      'tns:MaterieelDeelNummer': '7631',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '242.58',
#      'tns:Snelheid': '136.0'},
#     'tns:TreinNummer': '1872'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.08494492405',
#       'tns:Longitude': '4.8927684279553',
#       'tns:MaterieelDeelNummer': '2421',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.0856001403',
#       'tns:Longitude': '4.8942868699336',
#       'tns:MaterieelDeelNummer': '2619',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '0.0',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '7868'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#      'tns:Hdop': '0.65',
#      'tns:Latitude': '51.719016',
#      'tns:Longitude': '5.28849333333',
#      'tns:MaterieelDeelNummer': '8746',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '153.15',
#      'tns:Snelheid': '93.0'},
#     'tns:TreinNummer': '2873'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.523048956074',
#       'tns:Longitude': '4.6998858516008',
#       'tns:MaterieelDeelNummer': '2974',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '311.3',
#       'tns:Snelheid': '28.8'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.389705234921',
#       'tns:Longitude': '4.6255538617772',
#       'tns:MaterieelDeelNummer': '2945',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '135.5',
#       'tns:Snelheid': '32.4'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.389713799978',
#       'tns:Longitude': '4.625544018937',
#       'tns:MaterieelDeelNummer': '2112',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '137.0',
#       'tns:Snelheid': '21.6'}],
#     'tns:TreinNummer': '4864'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.92468229138',
#       'tns:Longitude': '4.4641987885901',
#       'tns:MaterieelDeelNummer': '2454',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '243.2',
#       'tns:Snelheid': '32.4'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.924873027918',
#       'tns:Longitude': '4.4648280193801',
#       'tns:MaterieelDeelNummer': '2645',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '245.1',
#       'tns:Snelheid': '32.4'}],
#     'tns:TreinNummer': '4072'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.65',
#      'tns:Latitude': '51.491815',
#      'tns:Longitude': '5.40548633333',
#      'tns:MaterieelDeelNummer': '2503',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '331.49',
#      'tns:Snelheid': '140.0'},
#     'tns:TreinNummer': '5276'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:12Z',
#      'tns:Hdop': '50.0',
#      'tns:Latitude': '52.325045',
#      'tns:Longitude': '4.78055166667',
#      'tns:MaterieelDeelNummer': '8657',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '247.82',
#      'tns:Snelheid': '123.0'},
#     'tns:TreinNummer': '3168'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.44343',
#      'tns:Longitude': '5.48382',
#      'tns:MaterieelDeelNummer': '8645',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '77.58',
#      'tns:Snelheid': '39.0'},
#     'tns:TreinNummer': '871'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.63',
#       'tns:Latitude': '52.3506',
#       'tns:Longitude': '6.116845',
#       'tns:MaterieelDeelNummer': '4069',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '359.56',
#       'tns:Snelheid': '114.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.3515333333',
#       'tns:Longitude': '6.11688166667',
#       'tns:MaterieelDeelNummer': '4230',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '359.62',
#       'tns:Snelheid': '117.0'}],
#     'tns:TreinNummer': '3666'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '1.0',
#      'tns:Latitude': '52.066035740672',
#      'tns:Longitude': '5.3478356394627',
#      'tns:MaterieelDeelNummer': '2952',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '89.0',
#      'tns:Snelheid': '111.6'},
#     'tns:TreinNummer': '7373'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.8401066667',
#      'tns:Longitude': '5.25755333333',
#      'tns:MaterieelDeelNummer': '8653',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '353.68',
#      'tns:Snelheid': '127.0'},
#     'tns:TreinNummer': '3972'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.64',
#      'tns:Latitude': '51.9952741667',
#      'tns:Longitude': '5.98144683333',
#      'tns:MaterieelDeelNummer': '2229',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '234.48',
#      'tns:Snelheid': '31.0'},
#     'tns:TreinNummer': '7674'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.7025966667',
#       'tns:Longitude': '6.25145166667',
#       'tns:MaterieelDeelNummer': '7618',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '267.62',
#       'tns:Snelheid': '133.0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.7026933333',
#       'tns:Longitude': '6.25449333333',
#       'tns:MaterieelDeelNummer': '7527',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '267.61',
#       'tns:Snelheid': '133.0'}],
#     'tns:TreinNummer': '774'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.01599',
#      'tns:Longitude': '5.17981166667',
#      'tns:MaterieelDeelNummer': '8743',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '161.31',
#      'tns:Snelheid': '129.0'},
#     'tns:TreinNummer': '2075'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.6921016667',
#       'tns:Longitude': '5.29455666667',
#       'tns:MaterieelDeelNummer': '9552',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '109.49',
#       'tns:Snelheid': '0'},
#      {'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.6911583333',
#       'tns:Longitude': '5.29421',
#       'tns:MaterieelDeelNummer': '8707',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '117.8',
#       'tns:Snelheid': '0'}],
#     'tns:TreinNummer': '872'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.312473892669',
#      'tns:Longitude': '5.0431424868785',
#      'tns:MaterieelDeelNummer': '2622',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '4373'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:02Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.318441266919',
#       'tns:Longitude': '4.9417891610392',
#       'tns:MaterieelDeelNummer': '2409',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '330.4',
#       'tns:Snelheid': '75.6'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.322130209981',
#       'tns:Longitude': '4.9382225441835',
#       'tns:MaterieelDeelNummer': '2420',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '330.0',
#       'tns:Snelheid': '50.4'}],
#     'tns:TreinNummer': '4068'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '0.64',
#      'tns:Latitude': '52.7979273333',
#      'tns:Longitude': '6.50066',
#      'tns:MaterieelDeelNummer': '4040',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '12.39',
#      'tns:Snelheid': '137.0'},
#     'tns:TreinNummer': '8167'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#       'tns:Hdop': '0.8',
#       'tns:Latitude': '52.067780376955',
#       'tns:Longitude': '5.1418965021942',
#       'tns:MaterieelDeelNummer': '2456',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '151.3',
#       'tns:Snelheid': '39.6'},
#      {'tns:AantalSatelieten': '0',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:18Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.068479123814',
#       'tns:Longitude': '5.1412986544663',
#       'tns:MaterieelDeelNummer': '2635',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '152.3',
#       'tns:Snelheid': '46.8'}],
#     'tns:TreinNummer': '6975'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '8',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '1.0',
#      'tns:Latitude': '51.462165',
#      'tns:Longitude': '5.75223333333',
#      'tns:MaterieelDeelNummer': '8675',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '285.14',
#      'tns:Snelheid': '127.0'},
#     'tns:TreinNummer': '3576'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.7',
#      'tns:Latitude': '51.685168',
#      'tns:Longitude': '5.2913675',
#      'tns:MaterieelDeelNummer': '2218',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '14.46',
#      'tns:Snelheid': '39.0'},
#     'tns:TreinNummer': '4474'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '11',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '52.6759333333',
#       'tns:Longitude': '6.19771833333',
#       'tns:MaterieelDeelNummer': '4209',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '173.92',
#       'tns:Snelheid': '112.0'},
#      {'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#       'tns:Hdop': '0.63',
#       'tns:Latitude': '52.6782006667',
#       'tns:Longitude': '6.19723083333',
#       'tns:MaterieelDeelNummer': '4059',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '171.14',
#       'tns:Snelheid': '109.0'}],
#     'tns:TreinNummer': '674'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.16773492393',
#      'tns:Longitude': '4.4837155618695',
#      'tns:MaterieelDeelNummer': '2617',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '4664'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
# ...
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '135.82',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '2179'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.379953321118',
#      'tns:Longitude': '4.8984886434739',
#      'tns:MaterieelDeelNummer': '2616',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '5868'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#      'tns:Hdop': '0.68',
#      'tns:Latitude': '51.4559065',
#      'tns:Longitude': '5.78827033333',
#      'tns:MaterieelDeelNummer': '2214',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '9669'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.172884749532',
#      'tns:Longitude': '5.3102910625548',
#      'tns:MaterieelDeelNummer': '2658',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '5573'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.66',
#      'tns:Latitude': '52.1516021667',
#      'tns:Longitude': '4.46212916667',
#      'tns:MaterieelDeelNummer': '9426',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '39.4',
#      'tns:Snelheid': '111.0'},
#     'tns:TreinNummer': '2166'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.388307567279',
#      'tns:Longitude': '4.6366095800927',
#      'tns:MaterieelDeelNummer': '2960',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '6381'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.178696063309',
#      'tns:Longitude': '5.1798059237797',
#      'tns:MaterieelDeelNummer': '2427',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '14972'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.387326707782',
#      'tns:Longitude': '4.8369910324091',
#      'tns:MaterieelDeelNummer': '2455',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '3377'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '0.63',
#      'tns:Latitude': '52.4278223333',
#      'tns:Longitude': '6.13820016667',
#      'tns:MaterieelDeelNummer': '4233',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '160.34',
#      'tns:Snelheid': '127.0'},
#     'tns:TreinNummer': '3679'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.078885955892',
#      'tns:Longitude': '5.1217686321143',
#      'tns:MaterieelDeelNummer': '2613',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '7368'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.8448683333',
#      'tns:Longitude': '5.85300833333',
#      'tns:MaterieelDeelNummer': '8664',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '20.69',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '3174'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.2138083333',
#      'tns:Longitude': '6.00018833333',
#      'tns:MaterieelDeelNummer': '8642',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '134.81',
#      'tns:Snelheid': '114.0'},
#     'tns:TreinNummer': '869'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.077135',
#      'tns:Longitude': '5.126105',
#      'tns:MaterieelDeelNummer': '9550',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '299.79',
#      'tns:Snelheid': '78.0'},
#     'tns:TreinNummer': '870'},
#    {'tns:TreinMaterieelDelen': [{'tns:AantalSatelieten': '8',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#       'tns:Hdop': '1.0',
#       'tns:Latitude': '51.501675',
#       'tns:Longitude': '5.39649333333',
#       'tns:MaterieelDeelNummer': '9518',
#       'tns:Materieelvolgnummer': '1',
#       'tns:Orientatie': '0',
#       'tns:Richting': '150.49',
#       'tns:Snelheid': '124.0'},
#      {'tns:AantalSatelieten': '12',
#       'tns:Berichttype': None,
#       'tns:Bron': 'NTT',
#       'tns:Elevation': '0.0',
#       'tns:Fix': '1',
#       'tns:GpsDatumTijd': '2018-04-28T18:27:01Z',
#       'tns:Hdop': '0.9',
#       'tns:Latitude': '51.5098033333',
#       'tns:Longitude': '5.38913566667',
#       'tns:MaterieelDeelNummer': '9514',
#       'tns:Materieelvolgnummer': '2',
#       'tns:Orientatie': '0',
#       'tns:Richting': '149.53',
#       'tns:Snelheid': '106.0'}],
#     'tns:TreinNummer': '3971'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.5786316667',
#      'tns:Longitude': '5.32645166667',
#      'tns:MaterieelDeelNummer': '8665',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '330.43',
#      'tns:Snelheid': '131.0'},
#     'tns:TreinNummer': '3574'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:20Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.1536816667',
#      'tns:Longitude': '5.36879333333',
#      'tns:MaterieelDeelNummer': '4076',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '266.82',
#      'tns:Snelheid': '32.0'},
#     'tns:TreinNummer': '1572'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.0243483333',
#      'tns:Longitude': '4.33896666667',
#      'tns:MaterieelDeelNummer': '8646',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '321.88',
#      'tns:Snelheid': '106.0'},
#     'tns:TreinNummer': '2277'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:21Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '51.2290233333',
#      'tns:Longitude': '5.97171',
#      'tns:MaterieelDeelNummer': '9553',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '278.87',
#      'tns:Snelheid': '78.0'},
#     'tns:TreinNummer': '3976'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.458768008656',
#      'tns:Longitude': '4.8056560953778',
#      'tns:MaterieelDeelNummer': '2642',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '4066'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.316774399745',
#      'tns:Longitude': '5.096250623261',
#      'tns:MaterieelDeelNummer': '2638',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '267.6',
#      'tns:Snelheid': '122.4'},
#     'tns:TreinNummer': '4370'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '7',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:27Z',
#      'tns:Hdop': '1.1',
#      'tns:Latitude': '52.0663',
#      'tns:Longitude': '5.15389833333',
#      'tns:MaterieelDeelNummer': '8666',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '115.33',
#      'tns:Snelheid': '129.0'},
#     'tns:TreinNummer': '3073'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:23Z',
#      'tns:Hdop': '0.64',
#      'tns:Latitude': '51.813914',
#      'tns:Longitude': '5.74220733333',
#      'tns:MaterieelDeelNummer': '2506',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '251.62',
#      'tns:Snelheid': '90.0'},
#     'tns:TreinNummer': '4475'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.67',
#      'tns:Latitude': '51.8070675',
#      'tns:Longitude': '4.66899566667',
#      'tns:MaterieelDeelNummer': '2523',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '6674'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:28Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.312408830818',
#      'tns:Longitude': '5.0435167858854',
#      'tns:MaterieelDeelNummer': '2429',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '15873'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:24:51Z',
#      'tns:Hdop': '0.7',
#      'tns:Latitude': '52.297083',
#      'tns:Longitude': '4.72939366667',
#      'tns:MaterieelDeelNummer': '8652',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '77.59',
#      'tns:Snelheid': '120.0'},
#     'tns:TreinNummer': '3177'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:25Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '53.0926416667',
#      'tns:Longitude': '5.82092',
#      'tns:MaterieelDeelNummer': '4052',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '163.35',
#      'tns:Snelheid': '63.0'},
#     'tns:TreinNummer': '9078'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '11',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.9',
#      'tns:Latitude': '52.4012783333',
#      'tns:Longitude': '5.295445',
#      'tns:MaterieelDeelNummer': '8702',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '60.88',
#      'tns:Snelheid': '104.0'},
#     'tns:TreinNummer': '2462'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:26Z',
#      'tns:Hdop': '0.64',
#      'tns:Latitude': '52.106512',
#      'tns:Longitude': '4.40444033333',
#      'tns:MaterieelDeelNummer': '9425',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '47.87',
#      'tns:Snelheid': '139.0'},
#     'tns:TreinNummer': '2466'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '0',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:19Z',
#      'tns:Hdop': '0.8',
#      'tns:Latitude': '52.322715853223',
#      'tns:Longitude': '5.0223762943608',
#      'tns:MaterieelDeelNummer': '2406',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '305.1',
#      'tns:Snelheid': '28.8'},
#     'tns:TreinNummer': '5768'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:22Z',
#      'tns:Hdop': '0.69',
#      'tns:Latitude': '51.6893595',
#      'tns:Longitude': '5.292923',
#      'tns:MaterieelDeelNummer': '2224',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '0.0',
#      'tns:Snelheid': '0'},
#     'tns:TreinNummer': '9673'},
#    {'tns:TreinMaterieelDelen': {'tns:AantalSatelieten': '12',
#      'tns:Berichttype': None,
#      'tns:Bron': 'NTT',
#      'tns:Elevation': '0.0',
#      'tns:Fix': '1',
#      'tns:GpsDatumTijd': '2018-04-28T18:27:24Z',
#      'tns:Hdop': '0.63',
#      'tns:Latitude': '52.4923921667',
#      'tns:Longitude': '4.77841216667',
#      'tns:MaterieelDeelNummer': '8640',
#      'tns:Materieelvolgnummer': '1',
#      'tns:Orientatie': '0',
#      'tns:Richting': '289.46',
#      'tns:Snelheid': '96.0'},
#     'tns:TreinNummer': '3066'}]}}

# %%
m = client.topics[b'ndovloketnl-gps'].get_simple_consumer(
    auto_offset_reset=OffsetType.EARLIEST,
    reset_offset_on_start=True
)

# %%
m.consume().offset
# Out:
# 15786

# %% [markdown]
# We can see that the message has the following structure:
#
# ```
# {
#   'tns:ArrayOfTreinLocation': {
#     'tns:TreinLocation': [
#       <train_info_1>,
#       <train_info_2>,
#       ...
#     ]
#   }
# }
# ```
#
# With the `<train_info_x>` messages containing:
# - `tns:TreinNummer`: the train number. This number is used in passenger information displays.
# - `tns:MaterieelDeelNummer`: the train car number. It identifies the physical train car.
# - `tns:Materieelvolgnummer`: the car position. 1 is the car in front of the train, 2 the next one, etc.
# - `tns:GpsDatumTijd`: the datetime given by the GPS.
# - `tns:Latitude`, `tns:Longitude`, `tns:Elevation`: 3D coordinates given by the GPS.
# - `tns:Snelheid`: speed, most likely given by the GPS.
# - `tns:Richting`: heading, most likely given by the GPS.
# - `tns:AantalSatelieten`: number of GPS satellites in view.
#
# We also notice that when a train is composed of multiple cars, the position is given in an array, with the position of all individual cars.

# %% [markdown]
# **Question I.a. (5/20)** Write a function which extracts the train number, train car and GPS data from the source messages. Using this function, you should be able to obtain the example table, or something similar.

# %%
import numpy as np
import pandas as pd

# %%
def extract_gps_data(msg):
    trains = msg['tns:ArrayOfTreinLocation']['tns:TreinLocation']
    data = []
    for train in trains:
        train_nb = int(train['tns:TreinNummer'])
        cars = train['tns:TreinMaterieelDelen']
        if (type(cars) is not list):
            cars = [cars]
        for car in cars:
            car_nb = car['tns:MaterieelDeelNummer']
            car_pos = car['tns:Materieelvolgnummer']
            tms = car['tns:GpsDatumTijd']
            lat = car['tns:Latitude']
            long = car['tns:Longitude']
            elev = car['tns:Elevation']
            speed = car['tns:Snelheid']
            heading = car['tns:Richting']
            num_gps = car['tns:AantalSatelieten']
            data.append([tms, train_nb, car_nb, car_pos, lat, long, elev, heading, speed])
    return data

# %%
def prettify(json):
    df = pd.DataFrame(
    data=extract_gps_data(json),
    columns=['timestamp', 'train_number', 'car_number', 'car_position', 'latitude', 'longitude', 'elevation', 'heading', 'speed'])
    df.timestamp = pd.to_datetime(df.timestamp, unit='ns')
    return df

# %%
import numpy as np
import pandas as pd

prettify(json.loads(example_gps.value)).head(n=20)
# Out:
#              timestamp  train_number car_number car_position         latitude  \
# 0  2018-04-28 18:27:26          3671       4240            1    51.5608216667
# 1  2018-04-28 18:27:27          3671       4032            2         51.56064
# 2  2018-04-28 18:27:20          4873       2961            1  52.678516391842
# 3  2018-04-28 18:27:19          3674       4064            1    51.5958383333
# 4  2018-04-28 18:27:28          3674       4244            2    51.5958383333
# 5  2018-04-28 18:27:19          3670       4060            1         51.87381
# 6  2018-04-28 18:27:20          3670       4241            2         51.87345
# 7  2018-04-28 18:27:21         14675       2410            1  52.362051626752
# 8  2018-04-28 18:27:20          3072       9402            1    51.9852116667
# 9  2018-04-28 18:27:27          3170       9576            1       52.1068345
# 10 2018-04-28 18:27:27          3170       9522            2    52.1060966667
# 11 2018-04-28 18:27:27          4077       2416            1  52.355876035642
# 12 2018-04-28 18:27:21          4077       2411            2  52.356496909211
# 13 2018-04-28 18:27:17          7866       2460            1   52.01148166349
# 14 2018-04-28 18:27:19          7866       2621            2  52.011156186449
# 15 2018-04-28 18:27:26           769       7617            1    52.6394338333
# 16 2018-04-28 18:27:27          7877       2436            1  52.085304668655
# 17 2018-04-28 18:27:18          7877       2650            2   52.08494481708
# 18 2018-04-28 18:27:21          3969       8644            1    51.2449316667
# 19 2018-04-28 18:27:19          3969       9420            2    51.2451633333
#
#           longitude elevation heading  speed
# 0            5.0829       0.0  150.96      0
# 1     5.08481666667       0.0   36.95      0
# 2   4.8996640175703       0.0    90.9   50.4
# 3     4.79456333333       0.0   86.01   38.0
# 4           4.79422       0.0   86.23   51.0
# 5     5.85875833333       0.0  357.03  134.0
# 6     5.85880333333       0.0  357.01  135.0
# 7   4.9310855568925       0.0   172.6   43.2
# 8     5.90010166667       0.0  114.24      0
# 9     5.08332333333       0.0  313.22  112.0
# 10    5.08451333333       0.0  313.06  112.0
# 11  4.9198526270407       0.0   244.9   64.8
# 12  4.9220207911214       0.0   244.2   64.8
# 13  4.6367337018792       0.0   292.1  126.0
# 14  4.6380594260477       0.0   292.1  122.4
# 15    6.22614533333       0.0  329.86  126.0
# 16   4.894688140372       0.0     0.0      0
# 17   4.893708016236       0.0    59.5   10.8
# 18           5.7614       0.0   96.15  136.0
# 19    5.75796166667       0.0   96.25  136.0

# %% [markdown]
# **Question I.b (15/20)** Make a live plot of the train positions.
#
# You can do so by using bokeh; use last week's lab as an example.
# See also: https://bokeh.pydata.org/en/latest/docs/user_guide/geo.html
#
# To use the maps in bokeh, you will likely need to convert GPS coordinates to web mercator:
# https://gis.stackexchange.com/questions/247871/convert-gps-coordinates-to-web-mercator-epsg3857-using-python-pyproj
#
# You can compare your plot to one of the live services: https://spoorkaart.mwnn.nl/, http://treinenradar.nl/
#
# **Care should be taken for the following points.**
# - We expect the train positions to fall on rail tracks on the map.
# - Trains on the map should not appear/disappear when data is absent for a few messages.
# - Provide interactive label with the train number (we do not expect train type, as this needs to be recovered from other sources).
# - If possible, find a way to show where the train is heading.

# %%
def update(df, update):
    for i in range(len(update)):
        entry = update.loc[i]
        
        # Test if data is missing
        try:
            long_ = float(entry.latitude)
            lat_ = float(entry.longitude)
        except: 
            pass
        tr_nb = entry.train_number
        car_nb = entry.car_number
        car_pos = entry.car_position
        
        query = df[(df.train_number == tr_nb) & (df.car_number == car_nb) & (df.car_position == car_pos)]    
        if len(query) == 1: # if this entry already exists in our database, update it
            idx = query.index[0]
            df.drop(idx, inplace=True)
    
        df = df.append(entry)
        df.reset_index(drop=True, inplace=True)
        df.latitude = df.latitude.map(lambda x: float(x))
        df.longitude = df.longitude.map(lambda x: float(x))
    return df

# %%
cols = ['timestamp', 'train_number', 'car_number', 'car_position', 'latitude', 'longitude', 'elevation', 'heading', 'speed']

# %%
from pyproj import Proj, transform
def to_mercator(long, lat):
    c1, c2 = transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), long, lat)
    return c1, c2

# %%
consumer =  client.topics[b'ndovloketnl-gps'].get_simple_consumer(auto_offset_reset=OffsetType.LATEST,reset_offset_on_start=True)

# %%
import time
from bokeh.io import push_notebook, output_notebook, show
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.tile_providers import CARTODBPOSITRON

# %%
cols=['timestamp', 'train_number', 'car_number', 'car_position', 'latitude', 'longitude', 'elevation', 'heading', 'speed']        
output_notebook()
    
initial_state = pd.DataFrame(data=extract_gps_data(json.loads(consumer.consume().value)), columns= cols)

# Define the data
x = []
y = []
labels_ = []

# Define the source
source = ColumnDataSource(data=dict(x=x, y=y, labels=labels_))

# Define the figure
p = figure(x_range=(3.6e5, 8.4e5), y_range=(6.56e6, 7.1e6))
p.add_tile(CARTODBPOSITRON)

# Define the circles
p.circle(x='x', y= 'y', size=15, source=source, color='yellow', fill_color="red", alpha=.5)

# Set the LabelSet
labels_set = LabelSet(x='x', y='y', text='labels', x_offset=-5, y_offset=-5, level='glyph',\
                      text_font_size='6pt',source=source, render_mode='canvas')

# Add labels
p.add_layout(labels_set)

# Show the notebook
handle=show(p, notebook_handle=True)

try:
    for message in consumer:
        if message is not None:
            data_ = extract_gps_data(json.loads(message.value))
            state = pd.DataFrame(data=data_, columns= cols)
            df = update(initial_state, state)
            df = df[df.car_position == '1']
            x = list(df.longitude.values)
            y = list(df.latitude.values)
            labels_ = list(df.train_number.values)
            x_, y_ = to_mercator(x, y)
            source.data = dict(x=x_, y=y_, labels=labels_)
            push_notebook(handle=handle)
            time.sleep(3)
except KeyboardInterrupt:
    pass
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2e858a12-c657-4e6b-85e0-5e9a1f82dc54">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4eea237a-0a76-4d35-9bdd-11f8dcea83ba"></div>
# </div>

# %% [markdown]
# **N.B: It takes up to 10 seconds for the points to show on the graph, after that their positions update smoothly.**

# %% [markdown]
# # Part II - Live stopping time (20 points / 60)

# %% [markdown]
# In this part, we will have a look at the two other streams, namely `ndovloketnl-arrivals` and `ndovloketnl-departures`. Each time a train arrives at or leaves a station, a message is generated. Let's have a look at the content.

# %%
import json
from pykafka.common import OffsetType

example_arrivals = client.topics[b'ndovloketnl-arrivals'].get_simple_consumer(
    auto_offset_reset=OffsetType.EARLIEST,
    reset_offset_on_start=True
).consume()
json.loads(example_arrivals.value)
# Out:
# {'ns1:PutReisInformatieBoodschapIn': {'@xmlns:ns1': 'urn:ndov:cdm:trein:reisinformatie:messages:dynamischeaankomststaat:1',
#   '@xmlns:ns2': 'urn:ndov:cdm:trein:reisinformatie:data:4',
#   'ns2:ReisInformatieProductDAS': {'@TimeStamp': '2018-04-28T21:07:58.090Z',
#    '@Versie': '6.1',
#    'ns2:DynamischeAankomstStaat': {'ns2:RitDatum': '2018-04-28',
#     'ns2:RitId': '7079',
#     'ns2:RitStation': {'ns2:KorteNaam': 'Almelo',
#      'ns2:LangeNaam': 'Almelo',
#      'ns2:MiddelNaam': 'Almelo',
#      'ns2:StationCode': 'AML',
#      'ns2:Type': '5',
#      'ns2:UICCode': '8400051'},
#     'ns2:TreinAankomst': {'ns2:AankomstTijd': [{'#text': '2018-04-28T21:07:00.000Z',
#        '@InfoStatus': 'Gepland'},
#       {'#text': '2018-04-28T21:10:12.000Z', '@InfoStatus': 'Actueel'}],
#      'ns2:ExacteAankomstVertraging': 'PT3M12S',
#      'ns2:GedempteAankomstVertraging': 'PT5M',
#      'ns2:PresentatieAankomstVertraging': {'ns2:Uitingen': {'ns2:Uiting': '+3 min.'}},
#      'ns2:PresentatieTreinAankomstSpoor': {'ns2:Uitingen': {'ns2:Uiting': '2a'}},
#      'ns2:PresentatieTreinHerkomst': {'ns2:Uitingen': {'ns2:Uiting': 'Apeldoorn'}},
#      'ns2:PresentatieVerkorteRouteHerkomst': {'ns2:Uitingen': {'ns2:Uiting': 'Deventer, Wierden'}},
#      'ns2:TreinAankomstSpoor': [{'@InfoStatus': 'Gepland',
#        'ns2:SpoorFase': 'a',
#        'ns2:SpoorNummer': '2'},
#       {'@InfoStatus': 'Actueel',
#        'ns2:SpoorFase': 'a',
#        'ns2:SpoorNummer': '2'}],
#      'ns2:TreinHerkomst': [{'@InfoStatus': 'Gepland',
#        'ns2:KorteNaam': 'Apeldoorn',
#        'ns2:LangeNaam': 'Apeldoorn',
#        'ns2:MiddelNaam': 'Apeldoorn',
#        'ns2:StationCode': 'APD',
#        'ns2:Type': '5',
#        'ns2:UICCode': '8400066'},
#       {'@InfoStatus': 'Actueel',
#        'ns2:KorteNaam': 'Apeldoorn',
#        'ns2:LangeNaam': 'Apeldoorn',
#        'ns2:MiddelNaam': 'Apeldoorn',
#        'ns2:StationCode': 'APD',
#        'ns2:Type': '5',
#        'ns2:UICCode': '8400066'}],
#      'ns2:TreinNummer': '7079',
#      'ns2:TreinSoort': {'#text': 'Sprinter', '@Code': 'SPR'},
#      'ns2:TreinStatus': '0',
#      'ns2:VerkorteRouteHerkomst': [{'@InfoStatus': 'Gepland',
#        'ns2:Station': [{'ns2:KorteNaam': 'Deventer',
#          'ns2:LangeNaam': 'Deventer',
#          'ns2:MiddelNaam': 'Deventer',
#          'ns2:StationCode': 'DV',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400173'},
#         {'ns2:KorteNaam': 'Wierden',
#          'ns2:LangeNaam': 'Wierden',
#          'ns2:MiddelNaam': 'Wierden',
#          'ns2:StationCode': 'WDN',
#          'ns2:Type': '1',
#          'ns2:UICCode': '8400691'}]},
#       {'@InfoStatus': 'Actueel',
#        'ns2:Station': [{'ns2:KorteNaam': 'Deventer',
#          'ns2:LangeNaam': 'Deventer',
#          'ns2:MiddelNaam': 'Deventer',
#          'ns2:StationCode': 'DV',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400173'},
#         {'ns2:KorteNaam': 'Wierden',
#          'ns2:LangeNaam': 'Wierden',
#          'ns2:MiddelNaam': 'Wierden',
#          'ns2:StationCode': 'WDN',
#          'ns2:Type': '1',
#          'ns2:UICCode': '8400691'}]}],
#      'ns2:Vervoerder': 'NS',
#      'ns2:WijzigingHerkomst': {'ns2:WijzigingType': '11'}}},
#    'ns2:RIPAdministratie': {'ns2:AbonnementId': '55',
#     'ns2:ReisInformatieProductID': '1804282307582200002',
#     'ns2:ReisInformatieTijdstip': '2018-04-28T21:07:00.000Z'}}}}

# %%
example_departures = client.topics[b'ndovloketnl-departures'].get_simple_consumer(
    auto_offset_reset=OffsetType.EARLIEST,
    reset_offset_on_start=True
).consume()
json.loads(example_departures.value)
# Out:
# {'ns1:PutReisInformatieBoodschapIn': {'@xmlns:ns1': 'urn:ndov:cdm:trein:reisinformatie:messages:5',
#   '@xmlns:ns2': 'urn:ndov:cdm:trein:reisinformatie:data:4',
#   'ns2:ReisInformatieProductDVS': {'@TimeStamp': '2018-04-29T12:06:35.345Z',
#    '@Versie': '6.2',
#    'ns2:DynamischeVertrekStaat': {'ns2:RitDatum': '2018-04-29',
#     'ns2:RitId': '5144',
#     'ns2:RitStation': {'ns2:KorteNaam': 'Rotterdam',
#      'ns2:LangeNaam': 'Rotterdam Centraal',
#      'ns2:MiddelNaam': 'Rotterdam C.',
#      'ns2:StationCode': 'RTD',
#      'ns2:Type': '6',
#      'ns2:UICCode': '8400530'},
#     'ns2:Trein': {'ns2:AchterBlijvenAchtersteTreinDeel': 'N',
#      'ns2:AfstandPerronEindKopVertrekTrein': '0',
#      'ns2:ExacteVertrekVertraging': 'PT0S',
#      'ns2:GedempteVertrekVertraging': 'PT0S',
#      'ns2:NietInstappen': 'N',
#      'ns2:PresentatieTreinEindBestemming': {'ns2:Uitingen': {'ns2:Uiting': 'Den Haag Centraal'}},
#      'ns2:PresentatieTreinVertrekSpoor': {'ns2:Uitingen': {'ns2:Uiting': '9'}},
#      'ns2:PresentatieVerkorteRoute': {'ns2:Uitingen': {'ns2:Uiting': 'Delft, Den Haag HS'}},
#      'ns2:RangeerBeweging': 'N',
#      'ns2:Reserveren': 'N',
#      'ns2:SpeciaalKaartje': 'N',
#      'ns2:Toeslag': 'N',
#      'ns2:TreinEindBestemming': [{'@InfoStatus': 'Gepland',
#        'ns2:KorteNaam': 'Den Haag C',
#        'ns2:LangeNaam': 'Den Haag Centraal',
#        'ns2:MiddelNaam': 'Den Haag C.',
#        'ns2:StationCode': 'GVC',
#        'ns2:Type': '6',
#        'ns2:UICCode': '8400282'},
#       {'@InfoStatus': 'Actueel',
#        'ns2:KorteNaam': 'Den Haag C',
#        'ns2:LangeNaam': 'Den Haag Centraal',
#        'ns2:MiddelNaam': 'Den Haag C.',
#        'ns2:StationCode': 'GVC',
#        'ns2:Type': '6',
#        'ns2:UICCode': '8400282'}],
#      'ns2:TreinFormule': '1',
#      'ns2:TreinNummer': '5144',
#      'ns2:TreinSoort': {'#text': 'Sprinter', '@Code': 'SPR'},
#      'ns2:TreinStatus': '5',
#      'ns2:TreinVertrekSpoor': [{'@InfoStatus': 'Gepland',
#        'ns2:SpoorNummer': '9'},
#       {'@InfoStatus': 'Actueel', 'ns2:SpoorNummer': '9'}],
#      'ns2:TreinVleugel': {'ns2:MaterieelDeelDVS': [{'ns2:MaterieelAanduiding': '4',
#         'ns2:MaterieelDeelEindBestemming': [{'@InfoStatus': 'Gepland',
#           'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'},
#          {'@InfoStatus': 'Actueel',
#           'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'}],
#         'ns2:MaterieelDeelVertrekPositie': '1',
#         'ns2:MaterieelDeelVolgordeVertrek': '1',
#         'ns2:MaterieelLengte': '6940',
#         'ns2:MaterieelNummer': '000000-02444-0',
#         'ns2:MaterieelSoort': 'SLT',
#         'ns2:PresentatieMaterieelDeelEindBestemming': {'ns2:Uitingen': {'ns2:Uiting': 'Den Haag Centraal'}}},
#        {'ns2:MaterieelAanduiding': '6',
#         'ns2:MaterieelDeelEindBestemming': [{'@InfoStatus': 'Gepland',
#           'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'},
#          {'@InfoStatus': 'Actueel',
#           'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'}],
#         'ns2:MaterieelDeelVertrekPositie': '3',
#         'ns2:MaterieelDeelVolgordeVertrek': '2',
#         'ns2:MaterieelLengte': '10050',
#         'ns2:MaterieelNummer': '000000-02624-0',
#         'ns2:MaterieelSoort': 'SLT',
#         'ns2:PresentatieMaterieelDeelEindBestemming': {'ns2:Uitingen': {'ns2:Uiting': 'Den Haag Centraal'}}}],
#       'ns2:PresentatieTreinVleugelEindBestemming': {'ns2:Uitingen': {'ns2:Uiting': 'Den Haag Centraal'}},
#       'ns2:PresentatieTreinVleugelVertrekSpoor': {'ns2:Uitingen': {'ns2:Uiting': '9'}},
#       'ns2:StopStations': [{'@InfoStatus': 'Gepland',
#         'ns2:Station': [{'ns2:KorteNaam': 'Schiedam C',
#           'ns2:LangeNaam': 'Schiedam Centrum',
#           'ns2:MiddelNaam': 'Schiedam C.',
#           'ns2:StationCode': 'SDM',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400553'},
#          {'ns2:KorteNaam': 'Delft Z',
#           'ns2:LangeNaam': 'Delft Zuid',
#           'ns2:MiddelNaam': 'Delft Zuid',
#           'ns2:StationCode': 'DTZ',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400166'},
#          {'ns2:KorteNaam': 'Delft',
#           'ns2:LangeNaam': 'Delft',
#           'ns2:MiddelNaam': 'Delft',
#           'ns2:StationCode': 'DT',
#           'ns2:Type': '5',
#           'ns2:UICCode': '8400170'},
#          {'ns2:KorteNaam': 'Rijswijk',
#           'ns2:LangeNaam': 'Rijswijk',
#           'ns2:MiddelNaam': 'Rijswijk',
#           'ns2:StationCode': 'RSW',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400505'},
#          {'ns2:KorteNaam': 'Moerwijk',
#           'ns2:LangeNaam': 'Den Haag Moerwijk',
#           'ns2:MiddelNaam': 'Moerwijk',
#           'ns2:StationCode': 'GVMW',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400279'},
#          {'ns2:KorteNaam': 'Dn Haag HS',
#           'ns2:LangeNaam': 'Den Haag HS',
#           'ns2:MiddelNaam': 'Den Haag HS',
#           'ns2:StationCode': 'GV',
#           'ns2:Type': '5',
#           'ns2:UICCode': '8400280'},
#          {'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'}]},
#        {'@InfoStatus': 'Actueel',
#         'ns2:Station': [{'ns2:KorteNaam': 'Schiedam C',
#           'ns2:LangeNaam': 'Schiedam Centrum',
#           'ns2:MiddelNaam': 'Schiedam C.',
#           'ns2:StationCode': 'SDM',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400553'},
#          {'ns2:KorteNaam': 'Delft Z',
#           'ns2:LangeNaam': 'Delft Zuid',
#           'ns2:MiddelNaam': 'Delft Zuid',
#           'ns2:StationCode': 'DTZ',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400166'},
#          {'ns2:KorteNaam': 'Delft',
#           'ns2:LangeNaam': 'Delft',
#           'ns2:MiddelNaam': 'Delft',
#           'ns2:StationCode': 'DT',
#           'ns2:Type': '5',
#           'ns2:UICCode': '8400170'},
#          {'ns2:KorteNaam': 'Rijswijk',
#           'ns2:LangeNaam': 'Rijswijk',
#           'ns2:MiddelNaam': 'Rijswijk',
#           'ns2:StationCode': 'RSW',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400505'},
#          {'ns2:KorteNaam': 'Moerwijk',
#           'ns2:LangeNaam': 'Den Haag Moerwijk',
#           'ns2:MiddelNaam': 'Moerwijk',
#           'ns2:StationCode': 'GVMW',
#           'ns2:Type': '0',
#           'ns2:UICCode': '8400279'},
#          {'ns2:KorteNaam': 'Dn Haag HS',
#           'ns2:LangeNaam': 'Den Haag HS',
#           'ns2:MiddelNaam': 'Den Haag HS',
#           'ns2:StationCode': 'GV',
#           'ns2:Type': '5',
#           'ns2:UICCode': '8400280'},
#          {'ns2:KorteNaam': 'Den Haag C',
#           'ns2:LangeNaam': 'Den Haag Centraal',
#           'ns2:MiddelNaam': 'Den Haag C.',
#           'ns2:StationCode': 'GVC',
#           'ns2:Type': '6',
#           'ns2:UICCode': '8400282'}]}],
#       'ns2:TreinVleugelEindBestemming': [{'@InfoStatus': 'Gepland',
#         'ns2:KorteNaam': 'Den Haag C',
#         'ns2:LangeNaam': 'Den Haag Centraal',
#         'ns2:MiddelNaam': 'Den Haag C.',
#         'ns2:StationCode': 'GVC',
#         'ns2:Type': '6',
#         'ns2:UICCode': '8400282'},
#        {'@InfoStatus': 'Actueel',
#         'ns2:KorteNaam': 'Den Haag C',
#         'ns2:LangeNaam': 'Den Haag Centraal',
#         'ns2:MiddelNaam': 'Den Haag C.',
#         'ns2:StationCode': 'GVC',
#         'ns2:Type': '6',
#         'ns2:UICCode': '8400282'}],
#       'ns2:TreinVleugelVertrekSpoor': [{'@InfoStatus': 'Gepland',
#         'ns2:SpoorNummer': '9'},
#        {'@InfoStatus': 'Actueel', 'ns2:SpoorNummer': '9'}]},
#      'ns2:VerkorteRoute': [{'@InfoStatus': 'Gepland',
#        'ns2:Station': [{'ns2:KorteNaam': 'Delft',
#          'ns2:LangeNaam': 'Delft',
#          'ns2:MiddelNaam': 'Delft',
#          'ns2:StationCode': 'DT',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400170'},
#         {'ns2:KorteNaam': 'Dn Haag HS',
#          'ns2:LangeNaam': 'Den Haag HS',
#          'ns2:MiddelNaam': 'Den Haag HS',
#          'ns2:StationCode': 'GV',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400280'}]},
#       {'@InfoStatus': 'Actueel',
#        'ns2:Station': [{'ns2:KorteNaam': 'Delft',
#          'ns2:LangeNaam': 'Delft',
#          'ns2:MiddelNaam': 'Delft',
#          'ns2:StationCode': 'DT',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400170'},
#         {'ns2:KorteNaam': 'Dn Haag HS',
#          'ns2:LangeNaam': 'Den Haag HS',
#          'ns2:MiddelNaam': 'Den Haag HS',
#          'ns2:StationCode': 'GV',
#          'ns2:Type': '5',
#          'ns2:UICCode': '8400280'}]}],
#      'ns2:VertrekRichting': 'A',
#      'ns2:VertrekTijd': [{'#text': '2018-04-29T12:06:00.000Z',
#        '@InfoStatus': 'Gepland'},
#       {'#text': '2018-04-29T12:06:00.000Z', '@InfoStatus': 'Actueel'}],
#      'ns2:Vervoerder': 'NS',
#      'ns2:Wijziging': {'ns2:WijzigingType': '40'}}},
#    'ns2:RIPAdministratie': {'ns2:AbonnementId': '54',
#     'ns2:ReisInformatieProductID': '1804291406352300007',
#     'ns2:ReisInformatieTijdstip': '2018-04-29T12:06:00.000Z'}}}}

# %% [markdown]
# We can see that the messages have the following structure:
#
# ```
# {
#   'ns1:PutReisInformatieBoodschapIn': {
#     'ns2:ReisInformatieProductDVS' or 'ns2:ReisInformatieProductDAS': {
#       'ns2:DynamischeVertrekStaat' or 'ns2:DynamischeAankomstStaat': {
#           'ns2:RitStation': <station_info>,
#           'ns2:Trein' or 'ns2:TreinAankomst': {
#               'ns2:VertrekTijd' or 'ns2:AankomstTijd': [<planned_and_actual_times>],
#               'ns2:TreinNummer': <train_number>,
#               'ns2:TreinSoort': <kind_of_train>,
#               ...
#           }
#
#       }
#     }
#   }
# }
# ```
#
# We can see also that the train stations have a long name, a medium name, a short name, a three letters code and a kind of nummerical ID. When giving information about times, tracks, direction,... you will find sometimes the information twice with the status `Gepland` (which means planned, according to the schedule) and `Actueel`(which means the actual measured value).

# %% [markdown]
# **Question II.a. (5/20)** We want to compute the time a train stays at a station and get a real-time histogram for a given time window. First, write the parsing functions that will allow you to get the station ID and a name, the train ID, and the actual arrival and departure times.

# %%
def parse_train(json):
    body = json['ns1:PutReisInformatieBoodschapIn']
    body = body.get('ns2:ReisInformatieProductDAS') or body.get('ns2:ReisInformatieProductDVS')
    body = body.get('ns2:DynamischeAankomstStaat') or body.get('ns2:DynamischeVertrekStaat')
    station_name = body['ns2:RitStation']['ns2:LangeNaam']
    station_id = body['ns2:RitStation']['ns2:UICCode']
    body = body.get('ns2:TreinAankomst') or body.get('ns2:Trein')
    time = body.get('ns2:AankomstTijd') or body.get('ns2:VertrekTijd')
    planned_time = time[0]['#text']
    actual_time = time[1]['#text']
    train_id = body['ns2:TreinNummer']
    return train_id, station_id, station_name, actual_time

# %%
parse_train(json.loads(example_arrivals.value))
# Out:
# ('7079', '8400051', 'Almelo', '2018-04-28T21:10:12.000Z')

# %%
parse_train(json.loads(example_departures.value))
# Out:
# ('5144', '8400530', 'Rotterdam Centraal', '2018-04-29T12:06:00.000Z')

# %% [markdown]
# **Question II.b. (5/20)** Create two Spark streams from the arrivals and departures where the records are in the form (K, V) where K is a key that you will be using to join the two streams (think about what you will need to match) and V, the value containing the all extracted information.

# %%
sc_ = StreamingContext(sc, 10)
sc_.checkpoint(checkpoint)

# %%
arrival_stream = KafkaUtils.createStream(sc_, ZOOKEEPER_QUORUM, group_id, {'ndovloketnl-arrivals': 1})
departure_stream = KafkaUtils.createStream(sc_, ZOOKEEPER_QUORUM, group_id, {'ndovloketnl-departures': 1})

# %%
# Map the records of each stream to (K, V) pairs
# K = (train_id, station_id), V = actual departure/arrival time
my_arrival_stream = arrival_stream\
    .map(lambda x: (parse_train(json.loads(x[1]))[:2], parse_train(json.loads(x[1]))[3]))
my_departure_stream = departure_stream\
    .map(lambda x: (parse_train(json.loads(x[1]))[:2], parse_train(json.loads(x[1]))[3]))

# %%
my_arrival_stream.pprint()
my_departure_stream.pprint()
sc_.start()
# Out:
# -------------------------------------------
# Time: 2018-05-18 09:50:50
# -------------------------------------------
# (('32121', '8400424'), '2018-05-18T08:08:00.000Z')
# (('37838', '8400430'), '2018-05-18T08:08:00.000Z')
# (('1730', '8400055'), '2018-05-18T08:08:00.000Z')
# (('4724', '8400363'), '2018-05-18T08:08:00.000Z')
# (('7629', '8400519'), '2018-05-18T08:08:00.000Z')
# (('36826', '8400565'), '2018-05-18T08:08:00.000Z')
# (('37632', '8400697'), '2018-05-18T06:56:00.000Z')
# (('2829', '8400621'), '2018-05-18T06:59:34.000Z')
# (('7925', '8400124'), '2018-05-18T08:08:00.000Z')
# (('2235', '8400553'), '2018-05-18T07:47:00.000Z')
# ...
#
# -------------------------------------------
# Time: 2018-05-18 09:50:50
# -------------------------------------------
# (('6087', '8400606'), '2018-05-17T21:47:11.000Z')
# (('6087', '8400621'), '2018-05-17T21:44:25.000Z')
# (('14683', '8400360'), '2018-05-17T21:45:02.000Z')
# (('6087', '8400340'), '2018-05-17T21:52:43.000Z')
# (('8094', '8400454'), '2018-05-17T21:46:00.000Z')
# (('7988', '8400472'), '2018-05-17T21:44:27.000Z')
# (('7988', '8400472'), '2018-05-17T21:44:27.000Z')
# (('1786', '8400066'), '2018-05-17T21:44:00.000Z')
# (('32484', '8400582'), '2018-05-17T21:43:00.000Z')
# (('3581', '8400339'), '2018-05-17T21:46:00.000Z')
# ...

# %%
sc_.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2018-05-18 09:51:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 09:51:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 09:51:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 09:51:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 09:51:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-18 09:51:20
# -------------------------------------------

# %% [markdown]
# **Question II.c. (5/20)** Apply a window (possibly of different lengths, but both with 20s sliding interval) on each stream.
# Join the streams such that all stays of 5 minutes and less are captured by the join in the same RDD (you can ignore late messages) and two consecutive joined RDD don't overlap in terms of stays.

# %%
window_arrival_stream = my_arrival_stream.window(windowDuration=20, slideDuration=20)
window_departure_stream = my_departure_stream.window(windowDuration=300, slideDuration=20)
joined_stream = window_arrival_stream.join(window_departure_stream)

# %%
joined_stream.pprint()
sc_.start()
# Out:
# -------------------------------------------
# Time: 2018-05-18 09:52:10
# -------------------------------------------
# (('5026', '8400530'), ('2018-05-18T07:52:55.000Z', '2018-05-18T07:54:55.000Z'))
# (('5026', '8400530'), ('2018-05-18T07:52:55.000Z', '2018-05-18T07:54:55.000Z'))
# (('5026', '8400530'), ('2018-05-18T07:52:55.000Z', '2018-05-18T07:54:55.000Z'))
# (('5026', '8400530'), ('2018-05-18T07:52:55.000Z', '2018-05-18T07:54:55.000Z'))
# (('6933', '8400623'), ('2018-05-18T08:00:02.000Z', '2018-05-18T08:00:02.000Z'))
# (('6933', '8400606'), ('2018-05-18T07:57:16.000Z', '2018-05-18T07:57:16.000Z'))
# (('37321', '8400139'), ('2018-05-18T08:00:15.000Z', '2018-05-18T08:00:15.000Z'))
# (('14631', '8400080'), ('2018-05-18T07:54:00.000Z', '2018-05-18T07:55:00.000Z'))
# (('5135', '8400530'), ('2018-05-18T07:54:00.000Z', '2018-05-18T07:56:00.000Z'))
# (('32029', '8400362'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# ...

# %%
sc_.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2018-05-18 09:52:30
# -------------------------------------------
# (('2237', '8400180'), ('2018-05-18T07:53:00.000Z', '2018-05-18T07:54:00.000Z'))
# (('37721', '8400175'), ('2018-05-18T07:52:00.000Z', '2018-05-18T07:52:00.000Z'))
# (('3631', '8400495'), ('2018-05-18T07:55:00.000Z', '2018-05-18T07:55:00.000Z'))
# (('6937', '8400340'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# (('5139', '8400533'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# (('32335', '8400446'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# (('32536', '8400152'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# (('4722', '8400368'), ('2018-05-18T07:52:00.000Z', '2018-05-18T07:52:00.000Z'))
# (('36728', '8400386'), ('2018-05-18T07:51:00.000Z', '2018-05-18T07:52:00.000Z'))
# (('31129', '8400315'), ('2018-05-18T09:02:00.000Z', '2018-05-18T09:02:00.000Z'))
# ...
#
# -------------------------------------------
# Time: 2018-05-18 09:52:50
# -------------------------------------------

# %% [markdown]
# **Question II.d. (5/20)** On the joined stream, compute the length of each stay (you can round to the minute) and produce a stream of histograms. You don't need to plot them, a value/count array is enough.

# %%
def date(str_):
    return np.datetime64(str_)

# %%
minute = np.timedelta64(1,'m')
length_stay = joined_stream.mapValues(lambda x: np.round(np.abs((date(x[1])- date(x[0]))/minute)))

# %%
length_stay.pprint()
sc_.start()
# Out:
# -------------------------------------------
# Time: 2018-05-18 10:17:50
# -------------------------------------------
# (('3527', '8400172'), 0.0)
# (('37838', '8400369'), 0.0)
# (('37838', '8400369'), 2.0)
# (('37838', '8400369'), 2.0)
# (('37838', '8400369'), 2.0)
# (('37838', '8400369'), 2.0)
# (('37838', '8400369'), 0.0)
# (('37838', '8400369'), 0.0)
# (('37838', '8400369'), 0.0)
# (('37838', '8400369'), 2.0)
# ...
#
# -------------------------------------------
# Time: 2018-05-18 10:18:10
# -------------------------------------------
# (('4328', '8400194'), 2.0)
# (('4328', '8400194'), 0.0)
# (('4328', '8400194'), 2.0)
# (('4328', '8400056'), 0.0)
# (('14632', '8400235'), 0.0)
# (('4041', '8400057'), 0.0)
# (('5633', '8400690'), 0.0)
# (('4032', '8400194'), 0.0)
# (('4030', '8400507'), 6.0)
# (('4030', '8400507'), 1.0)
# ...

# %%
sc_.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2018-05-18 10:18:30
# -------------------------------------------
# (('7034', '8400185'), 0.0)
# (('32025', '8400449'), 0.0)
# (('32025', '8400449'), 0.0)
# (('32025', '8400449'), 0.0)
# (('5132', '8400279'), 0.0)
# (('14634', '8400081'), 0.0)
# (('30932', '8400688'), 0.0)
# (('30932', '8400688'), 1.0)
# (('30932', '8400688'), 0.0)
# (('7828', '8400651'), 0.0)
# ...
#
# -------------------------------------------
# Time: 2018-05-18 10:18:50
# -------------------------------------------

# %% [markdown]
# **Notice here that a stay of 0 means that the train didn't stop at the given station, we decided to count it anyway.**

# %%
length_count = length_stay.map(lambda x: x[1]).countByValue()
length_count.pprint()

# %%
# Count of the stays
sc_.start()
# Out:
# -------------------------------------------
# Time: 2018-05-18 10:22:50
# -------------------------------------------
# (0.0, 108)
# (8.0, 1)
# (1.0, 17)
# (2.0, 5)
# (7.0, 1)
# (3.0, 1)
#
# -------------------------------------------
# Time: 2018-05-18 10:23:10
# -------------------------------------------
# (0.0, 47)
# (5.0, 3)
# (1.0, 11)
# (6.0, 1)
# (2.0, 8)
# (3.0, 1)

# %%
sc_.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2018-05-18 10:23:30
# -------------------------------------------
# (0.0, 24)
# (1.0, 2)
# (3.0, 3)
#
# -------------------------------------------
# Time: 2018-05-18 10:23:50
# -------------------------------------------

# %% [markdown]
# # Part III - Uptime analysis (20 points / 60)
#
# In this part, we will use the available data to derive information about train operations.

# %% [markdown]
# **Question III.a (5/20)** Write a function to extract the median timestamp from a message of the `ndovloketnl-gps` topic. You can reuse the `extract_gps_data` function from part I.

# %%
def extract_gps_time_approx(msg):
    p = prettify(msg)
    n = len(p)
    idx = int(np.ceil((n-1)/2))
    return np.datetime64(list(p.timestamp.sort_values())[idx], unit='ns')

# %%
extract_gps_time_approx(json.loads(example_gps.value))
# Out:
# numpy.datetime64('2018-04-28T18:27:23.000000')

# %% [markdown]
# **Question III.b (5/20)** Using `fetch_message_at` and `extract_gps_time_approx`, write a function named `search_gps` to find the first offset for a given timestamp in the `ndovloketnl-gps` topic.
#
# More preciseley, if we note `offset = search_gps(ts)` where ts is a timestamp, then we have:
# ```
# ts <= extract_gps_time_approx(fetch_message_at('ndovloketnl-gps', offset))
# extract_gps_time_approx(fetch_message_at('ndovloketnl-gps', offset - 1)) < ts
# ```

# %%
def found(ts, offset):
    ts = np.datetime64(ts)
    msg1 = json.loads(fetch_message_at('ndovloketnl-gps', offset).value.decode())
    msg2 = json.loads(fetch_message_at('ndovloketnl-gps', offset - 1).value.decode())
    return ts <= extract_gps_time_approx(msg1) and extract_gps_time_approx(msg2) < ts

# %%
def binarySearch(ts, first, last):
    done = found(ts, first) 
    while first <= last and not done:
        midpoint = (first + last)//2
        if found(ts, midpoint):
            done = True
        else:
            msg = json.loads(fetch_message_at('ndovloketnl-gps', midpoint - 1).value.decode())
            if ts < extract_gps_time_approx(msg):
                last = midpoint - 1
            else:
                first = midpoint + 1
    return midpoint

# %%
def search_gps(ts):
    ts = np.datetime64(ts)
    topic = client.topics[b'ndovloketnl-gps']
    first_offset = topic.earliest_available_offsets()[0].offset[0]
    last_offset = topic.latest_available_offsets()[0].offset[0]
    return binarySearch(ts, first_offset, last_offset)

# %%
# Example results from `search_gps`
offset = search_gps(pd.Timestamp('2018-05-05'))
# Out:
# Offset reset for partition 0 to timestamp 15785 failed. Setting partition 0's internal counter to 15785
# Offset reset for partition 0 to timestamp 15784 failed. Setting partition 0's internal counter to 15784
# Offset reset for partition 0 to timestamp 99699 failed. Setting partition 0's internal counter to 99699
# Offset reset for partition 0 to timestamp 99698 failed. Setting partition 0's internal counter to 99698
# Offset reset for partition 0 to timestamp 99698 failed. Setting partition 0's internal counter to 99698
# Offset reset for partition 0 to timestamp 57741 failed. Setting partition 0's internal counter to 57741
# Offset reset for partition 0 to timestamp 57740 failed. Setting partition 0's internal counter to 57740
# Offset reset for partition 0 to timestamp 57740 failed. Setting partition 0's internal counter to 57740
# Offset reset for partition 0 to timestamp 78720 failed. Setting partition 0's internal counter to 78720
# Offset reset for partition 0 to timestamp 78719 failed. Setting partition 0's internal counter to 78719
# Offset reset for partition 0 to timestamp 78719 failed. Setting partition 0's internal counter to 78719
# Offset reset for partition 0 to timestamp 68230 failed. Setting partition 0's internal counter to 68230
# Offset reset for partition 0 to timestamp 68229 failed. Setting partition 0's internal counter to 68229
# Offset reset for partition 0 to timestamp 68229 failed. Setting partition 0's internal counter to 68229
# Offset reset for partition 0 to timestamp 73475 failed. Setting partition 0's internal counter to 73475
# Offset reset for partition 0 to timestamp 73474 failed. Setting partition 0's internal counter to 73474
# Offset reset for partition 0 to timestamp 73474 failed. Setting partition 0's internal counter to 73474
# Offset reset for partition 0 to timestamp 70852 failed. Setting partition 0's internal counter to 70852
# Offset reset for partition 0 to timestamp 70851 failed. Setting partition 0's internal counter to 70851
# Offset reset for partition 0 to timestamp 70851 failed. Setting partition 0's internal counter to 70851
# Offset reset for partition 0 to timestamp 69541 failed. Setting partition 0's internal counter to 69541
# Offset reset for partition 0 to timestamp 69540 failed. Setting partition 0's internal counter to 69540
# Offset reset for partition 0 to timestamp 69540 failed. Setting partition 0's internal counter to 69540
# Offset reset for partition 0 to timestamp 70196 failed. Setting partition 0's internal counter to 70196
# Offset reset for partition 0 to timestamp 70195 failed. Setting partition 0's internal counter to 70195
# Offset reset for partition 0 to timestamp 70195 failed. Setting partition 0's internal counter to 70195
# Offset reset for partition 0 to timestamp 69868 failed. Setting partition 0's internal counter to 69868
# Offset reset for partition 0 to timestamp 69867 failed. Setting partition 0's internal counter to 69867
# Offset reset for partition 0 to timestamp 69867 failed. Setting partition 0's internal counter to 69867
# Offset reset for partition 0 to timestamp 69704 failed. Setting partition 0's internal counter to 69704
# Offset reset for partition 0 to timestamp 69703 failed. Setting partition 0's internal counter to 69703
# Offset reset for partition 0 to timestamp 69703 failed. Setting partition 0's internal counter to 69703
# Offset reset for partition 0 to timestamp 69622 failed. Setting partition 0's internal counter to 69622
# Offset reset for partition 0 to timestamp 69621 failed. Setting partition 0's internal counter to 69621
# Offset reset for partition 0 to timestamp 69621 failed. Setting partition 0's internal counter to 69621
# Offset reset for partition 0 to timestamp 69581 failed. Setting partition 0's internal counter to 69581
# Offset reset for partition 0 to timestamp 69580 failed. Setting partition 0's internal counter to 69580
# Offset reset for partition 0 to timestamp 69580 failed. Setting partition 0's internal counter to 69580
# Offset reset for partition 0 to timestamp 69601 failed. Setting partition 0's internal counter to 69601
# Offset reset for partition 0 to timestamp 69600 failed. Setting partition 0's internal counter to 69600
# Offset reset for partition 0 to timestamp 69600 failed. Setting partition 0's internal counter to 69600
# Offset reset for partition 0 to timestamp 69611 failed. Setting partition 0's internal counter to 69611
# Offset reset for partition 0 to timestamp 69610 failed. Setting partition 0's internal counter to 69610
# Offset reset for partition 0 to timestamp 69610 failed. Setting partition 0's internal counter to 69610
# Offset reset for partition 0 to timestamp 69616 failed. Setting partition 0's internal counter to 69616
# Offset reset for partition 0 to timestamp 69615 failed. Setting partition 0's internal counter to 69615

# %%
offset
# Out:
# 69617

# %% [markdown]
# **Question III.c (5/20)** Using `search_gps`, create a spark RDD or dataframe containing the GPS data between `2018-05-02 23:00:00` and `2018-05-04 01:00:00` (covers May 3rd, with 1h margin). Your extract needs to contain the following fields: `timestamp`, `train_number`, `car_number`, `speed`.
#
# Now, filter on the `timestamp` field to only keep data between `2018-05-03 00:00:00` and `2018-05-04 00:00:00`.
#
# Note: you may find it useful to save the resulting dataset on disk.

# %%
# Create a static RDD containing the GPS data between 2018-05-02 23:00:00 and 2018-05-04 01:00:00
ts1 = np.datetime64('2018-05-02 23:00:00', unit='ns')
ts2 = np.datetime64('2018-05-04 01:00:00', unit='ns')
offset1 = search_gps(ts1)
offset2 = search_gps(ts2)
rdd = create_static_rdd_from_kafka(b'ndovloketnl-gps', offset1, offset2)
# Out:
# Offset reset for partition 0 to timestamp 15785 failed. Setting partition 0's internal counter to 15785
# Offset reset for partition 0 to timestamp 15784 failed. Setting partition 0's internal counter to 15784
# Offset reset for partition 0 to timestamp 100648 failed. Setting partition 0's internal counter to 100648
# Offset reset for partition 0 to timestamp 100647 failed. Setting partition 0's internal counter to 100647
# Offset reset for partition 0 to timestamp 100647 failed. Setting partition 0's internal counter to 100647
# Offset reset for partition 0 to timestamp 58216 failed. Setting partition 0's internal counter to 58216
# Offset reset for partition 0 to timestamp 58215 failed. Setting partition 0's internal counter to 58215
# Offset reset for partition 0 to timestamp 58215 failed. Setting partition 0's internal counter to 58215
# Offset reset for partition 0 to timestamp 37000 failed. Setting partition 0's internal counter to 37000
# Offset reset for partition 0 to timestamp 36999 failed. Setting partition 0's internal counter to 36999
# Offset reset for partition 0 to timestamp 36999 failed. Setting partition 0's internal counter to 36999
# Offset reset for partition 0 to timestamp 47608 failed. Setting partition 0's internal counter to 47608
# Offset reset for partition 0 to timestamp 47607 failed. Setting partition 0's internal counter to 47607
# Offset reset for partition 0 to timestamp 47607 failed. Setting partition 0's internal counter to 47607
# Offset reset for partition 0 to timestamp 52912 failed. Setting partition 0's internal counter to 52912
# Offset reset for partition 0 to timestamp 52911 failed. Setting partition 0's internal counter to 52911
# Offset reset for partition 0 to timestamp 52911 failed. Setting partition 0's internal counter to 52911
# Offset reset for partition 0 to timestamp 50260 failed. Setting partition 0's internal counter to 50260
# Offset reset for partition 0 to timestamp 50259 failed. Setting partition 0's internal counter to 50259
# Offset reset for partition 0 to timestamp 50259 failed. Setting partition 0's internal counter to 50259
# Offset reset for partition 0 to timestamp 51586 failed. Setting partition 0's internal counter to 51586
# Offset reset for partition 0 to timestamp 51585 failed. Setting partition 0's internal counter to 51585
# Offset reset for partition 0 to timestamp 51585 failed. Setting partition 0's internal counter to 51585
# Offset reset for partition 0 to timestamp 52249 failed. Setting partition 0's internal counter to 52249
# Offset reset for partition 0 to timestamp 52248 failed. Setting partition 0's internal counter to 52248
# Offset reset for partition 0 to timestamp 52248 failed. Setting partition 0's internal counter to 52248
# Offset reset for partition 0 to timestamp 51917 failed. Setting partition 0's internal counter to 51917
# Offset reset for partition 0 to timestamp 51916 failed. Setting partition 0's internal counter to 51916
# Offset reset for partition 0 to timestamp 51916 failed. Setting partition 0's internal counter to 51916
# Offset reset for partition 0 to timestamp 52083 failed. Setting partition 0's internal counter to 52083
# Offset reset for partition 0 to timestamp 52082 failed. Setting partition 0's internal counter to 52082
# Offset reset for partition 0 to timestamp 52082 failed. Setting partition 0's internal counter to 52082
# Offset reset for partition 0 to timestamp 52000 failed. Setting partition 0's internal counter to 52000
# Offset reset for partition 0 to timestamp 51999 failed. Setting partition 0's internal counter to 51999
# Offset reset for partition 0 to timestamp 51999 failed. Setting partition 0's internal counter to 51999
# Offset reset for partition 0 to timestamp 51958 failed. Setting partition 0's internal counter to 51958
# Offset reset for partition 0 to timestamp 51957 failed. Setting partition 0's internal counter to 51957
# Offset reset for partition 0 to timestamp 51957 failed. Setting partition 0's internal counter to 51957
# Offset reset for partition 0 to timestamp 51979 failed. Setting partition 0's internal counter to 51979
# Offset reset for partition 0 to timestamp 51978 failed. Setting partition 0's internal counter to 51978
# Offset reset for partition 0 to timestamp 51978 failed. Setting partition 0's internal counter to 51978
# Offset reset for partition 0 to timestamp 51968 failed. Setting partition 0's internal counter to 51968
# Offset reset for partition 0 to timestamp 51967 failed. Setting partition 0's internal counter to 51967
# Offset reset for partition 0 to timestamp 51967 failed. Setting partition 0's internal counter to 51967
# Offset reset for partition 0 to timestamp 51973 failed. Setting partition 0's internal counter to 51973
# Offset reset for partition 0 to timestamp 51972 failed. Setting partition 0's internal counter to 51972
# Offset reset for partition 0 to timestamp 51972 failed. Setting partition 0's internal counter to 51972
# Offset reset for partition 0 to timestamp 51976 failed. Setting partition 0's internal counter to 51976
# Offset reset for partition 0 to timestamp 51975 failed. Setting partition 0's internal counter to 51975
# Offset reset for partition 0 to timestamp 15785 failed. Setting partition 0's internal counter to 15785
# Offset reset for partition 0 to timestamp 15784 failed. Setting partition 0's internal counter to 15784
# Offset reset for partition 0 to timestamp 100649 failed. Setting partition 0's internal counter to 100649
# Offset reset for partition 0 to timestamp 100648 failed. Setting partition 0's internal counter to 100648
# Offset reset for partition 0 to timestamp 100648 failed. Setting partition 0's internal counter to 100648
# Offset reset for partition 0 to timestamp 58216 failed. Setting partition 0's internal counter to 58216
# Offset reset for partition 0 to timestamp 58215 failed. Setting partition 0's internal counter to 58215
# Offset reset for partition 0 to timestamp 58215 failed. Setting partition 0's internal counter to 58215
# Offset reset for partition 0 to timestamp 79432 failed. Setting partition 0's internal counter to 79432
# Offset reset for partition 0 to timestamp 79431 failed. Setting partition 0's internal counter to 79431
# Offset reset for partition 0 to timestamp 79431 failed. Setting partition 0's internal counter to 79431
# Offset reset for partition 0 to timestamp 68824 failed. Setting partition 0's internal counter to 68824
# Offset reset for partition 0 to timestamp 68823 failed. Setting partition 0's internal counter to 68823
# Offset reset for partition 0 to timestamp 68823 failed. Setting partition 0's internal counter to 68823
# Offset reset for partition 0 to timestamp 63520 failed. Setting partition 0's internal counter to 63520
# Offset reset for partition 0 to timestamp 63519 failed. Setting partition 0's internal counter to 63519
# Offset reset for partition 0 to timestamp 63519 failed. Setting partition 0's internal counter to 63519
# Offset reset for partition 0 to timestamp 60868 failed. Setting partition 0's internal counter to 60868
# Offset reset for partition 0 to timestamp 60867 failed. Setting partition 0's internal counter to 60867
# Offset reset for partition 0 to timestamp 60867 failed. Setting partition 0's internal counter to 60867
# Offset reset for partition 0 to timestamp 62194 failed. Setting partition 0's internal counter to 62194
# Offset reset for partition 0 to timestamp 62193 failed. Setting partition 0's internal counter to 62193
# Offset reset for partition 0 to timestamp 62193 failed. Setting partition 0's internal counter to 62193
# Offset reset for partition 0 to timestamp 61531 failed. Setting partition 0's internal counter to 61531
# Offset reset for partition 0 to timestamp 61530 failed. Setting partition 0's internal counter to 61530
# Offset reset for partition 0 to timestamp 61530 failed. Setting partition 0's internal counter to 61530
# Offset reset for partition 0 to timestamp 61199 failed. Setting partition 0's internal counter to 61199
# Offset reset for partition 0 to timestamp 61198 failed. Setting partition 0's internal counter to 61198
# Offset reset for partition 0 to timestamp 61198 failed. Setting partition 0's internal counter to 61198
# Offset reset for partition 0 to timestamp 61365 failed. Setting partition 0's internal counter to 61365
# Offset reset for partition 0 to timestamp 61364 failed. Setting partition 0's internal counter to 61364
# Offset reset for partition 0 to timestamp 61364 failed. Setting partition 0's internal counter to 61364
# Offset reset for partition 0 to timestamp 61282 failed. Setting partition 0's internal counter to 61282
# Offset reset for partition 0 to timestamp 61281 failed. Setting partition 0's internal counter to 61281
# Offset reset for partition 0 to timestamp 61281 failed. Setting partition 0's internal counter to 61281
# Offset reset for partition 0 to timestamp 61323 failed. Setting partition 0's internal counter to 61323
# Offset reset for partition 0 to timestamp 61322 failed. Setting partition 0's internal counter to 61322
# Offset reset for partition 0 to timestamp 61322 failed. Setting partition 0's internal counter to 61322
# Offset reset for partition 0 to timestamp 61344 failed. Setting partition 0's internal counter to 61344
# Offset reset for partition 0 to timestamp 61343 failed. Setting partition 0's internal counter to 61343
# Offset reset for partition 0 to timestamp 61343 failed. Setting partition 0's internal counter to 61343
# Offset reset for partition 0 to timestamp 61333 failed. Setting partition 0's internal counter to 61333
# Offset reset for partition 0 to timestamp 61332 failed. Setting partition 0's internal counter to 61332
# Offset reset for partition 0 to timestamp 61332 failed. Setting partition 0's internal counter to 61332
# Offset reset for partition 0 to timestamp 61338 failed. Setting partition 0's internal counter to 61338
# Offset reset for partition 0 to timestamp 61337 failed. Setting partition 0's internal counter to 61337
# Offset reset for partition 0 to timestamp 61337 failed. Setting partition 0's internal counter to 61337
# Offset reset for partition 0 to timestamp 61335 failed. Setting partition 0's internal counter to 61335
# Offset reset for partition 0 to timestamp 61334 failed. Setting partition 0's internal counter to 61334
# Offset reset for partition 0 to timestamp 61334 failed. Setting partition 0's internal counter to 61334
# Offset reset for partition 0 to timestamp 61336 failed. Setting partition 0's internal counter to 61336
# Offset reset for partition 0 to timestamp 61335 failed. Setting partition 0's internal counter to 61335

# %%
ts1 = np.datetime64('2018-05-03 00:00:00')
ts2 = np.datetime64('2018-05-04 00:00:00')
#rdd = rdd.map(lambda x: x[(x.timestamp > ts1) & (x.timestamp < ts2)])
#rdd = rdd.filter(lambda x: len(x) > 0)

# %%
from pyspark.sql import Row, SQLContext
sqlContext = SQLContext(sc)

# %%
def parse_and_filter(json):
    Entry = Row('car_number', 'timestamp', 'speed')
    data = extract_gps_data(json)
    rows = []
    for row in data:
        rows.append(Row(car_number=row[2], timestamp=row[0], speed=row[8]))   
    return rows

# %%
# We parse the RDD and keep only the required fields
rdd = rdd.map(lambda x: parse_and_filter(json.loads(x[1])))
# We filter the RDD to keep only the data from 2018-05-03 00:00:00 to 2018-05-04 00:00:00
rdd = test.map(lambda x: [i for i in x if (np.datetime64(i.timestamp) > ts1) and (np.datetime64(i.timestamp) < ts2)])
rdd = test.filter(lambda x: len(x) > 0)

# %%
# Here is a preview of the first collected data 
sqlContext.createDataFrame(data=test.first()).show()
# Out:
# +----------+-----+--------------------+
# |car_number|speed|           timestamp|
# +----------+-----+--------------------+
# |      2117|    0|2018-05-03T00:00:07Z|
# |      4083| 40.0|2018-05-03T00:00:05Z|
# |      2450|    0|2018-05-03T00:00:06Z|
# +----------+-----+--------------------+

# %%
# Cache the RDD
rdd.cache()
# Out:
# PythonRDD[166] at RDD at PythonRDD.scala:48

# %% [markdown]
# **Question III.d (5/20)** We define the uptime as the time for which a given train car is being used. To compute it, we will consider 5 minutes slots. If the train car has a non-zero speed once within a 5 minutes slot, then we consider it being *up* for that time slot.
#
# Example: if we have the data point
# ```
# +----------+--------------------+------+
# |car_number|          timestamp | speed|
# +----------+--------------------+------+
# |      2418|2018-05-03T08:13:02Z| 136.8|
# +----------+--------------------+------+
# ```
# then we must consider that the train car `2418` was up during the `2018-05-03T08:10:00Z` to `2018-05-03T08:15:00Z` time slot.
#
# We expect this method to give a relatively good lower bound for the uptime.
#
# From the previous RDD/DataFrame, compute the uptime for all train cars for 03.05.2018.
# Plot the distribution of uptime.
#
# What can you tell from the results?

# %%
from pyspark.sql import Window
import pyspark.sql.functions as functions
window = Window.partitionBy('5mn').orderBy('timestamp')
uptime = sqlContext.createDataFrame(data=rdd).\
select('car_number', 'timestamp', 'speed').filter('speed > 0').sort('timestamp').show()

# %% [markdown]
# **The results show that the car train resources are well managed since the uptime for the train cars is evenly distributed.**
